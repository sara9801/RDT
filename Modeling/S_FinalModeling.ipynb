# %% [markdown]
# # Modeling for Social data<br>
#
# ## * Modeling 진행 과정
#     1. Preprocessing
#         - Data의 변수 확인(분포확인, 연속형 변수끼리 plot)
#         - 연속형 Data scaling
#     2. Model selection
#         - 머신러닝 모형 (rf & bart)
#             - k-fold를 활용하여 hyper parameter tuning
#                 - 기준은 만들어낸 지표 4개로 평균화
#                 - 가장 best한 hyper parameter 선택하여 fitting 진행
#             - train and test set에 대해 k-fold를 활용하여 performance check
#         - 회귀모형 (Multinomial Logistic regression & ordinal logistic regression)
#             - train and test set에 대해 k-fold를 활용하여 performance check
#     3. Model select
#         - 해당 팀에서 제시한 4가지 지표를 이용하여 model select
#     4. Model Fitting
#         - Model fitting
#             - train set (661개) 모두 사용
#             - 모든 train set으로 data scaling 진행
#         - 선택한 모형에 대해 가정 검정
#             - VIF (multicollinearity)
#             - variable selection
#         - 결과 해석
#             - 결과 해석 및 visualization
#     5. Estimation
#         - fitting한 모형을 이용. GRADE를 estimate
#         - variable들에 대해 train에 fitting한 function 사용하여 transform

# %% [markdown]
# ## 0. Install packages and specify functions
# #### Install packages

# %%
##c++ microsoft 설치 필요. requirement 참조
# !pip install xbart

# %%
#기본적인 packages 
import pandas as pd
import numpy as np
import os 
import copy
import time
import statistics as st

#split train and test set package
from sklearn.model_selection import train_test_split

#modling packages
from sklearn.ensemble import RandomForestClassifier #RF
from xbart import XBART #xbart
import statsmodels.api as sm #MLR
from statsmodels.miscmodels.ordinal_model import OrderedModel #OLR


#for testing
from scipy.stats import shapiro #shapiro test(정규성)
from scipy.stats import skew, kurtosis #왜도, 첨도 관련 패키지
from sklearn.preprocessing import QuantileTransformer #quantile transformation
from sklearn.preprocessing import StandardScaler #standardscaler
from scipy.stats import bartlett #등분산성 test
import scipy.stats
from statsmodels.stats.outliers_influence import variance_inflation_factor #VIR

#for perfromance check
from sklearn.metrics import confusion_matrix, plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

#K-fold packages
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

##plot packages
import matplotlib.pyplot as plt
import matplotlib
from pandas.plotting import scatter_matrix
import platform
import seaborn as sns

## data directory 설정
os.chdir("C:/Users/user/Desktop/ESG데이터")

# %% [markdown]
# #### specify functions
# - performance를 판단하는 지표에 대한 자세한 설명은 G_FinalModeling에 있으므로 생략
# - confusion matrix를 만들어주는 function : make_confusionmatrix
#     - social data와 environment data의 경우, Grade 1에 대한 수가 현저히 적다. 그로 인해 모델 선택에서 층화추출을 했을 때, test set에 Grade 1이 들어있지 않는 경우가 발생한다. 이때 confusion matrix는 9x9 행렬이 아닐 수 있기 때문에 따로 function을 만들어 confusion matrix가 9x9가 되도록 했다.
# - multinomial logistic regression에 대한 function
#     1) 모델링 후 summary 결과에 대해 회귀계수만 출력하는 function
#     2) 모델링 후 marginal summary 결과에 대해 회귀계수만 출력하는 function
#     3) 모델링 후 summary 결과에 대해 p-value만 출력하는 function
#     4) 모델링 후 marginal summary 결과에 대해 p-value만 출력하는 function

# %%
#### performance를 판단하는 지표 4가지

#arg 설명
##m : confusion matrix 

#1. accuracy 계산 function
def acc(m) :
    return sum(np.diag(m))/np.sum(m)

#2. 근접정확도 계산 function
def nearest_acc(m) :
    total_sum = np.sum(m)
    near_sum = 0
    for i in range(8) :
        near_sum += m[i,i+1] + m[i+1,i]
    diag_sum = sum(np.diag(m))
    return (near_sum + diag_sum) / total_sum

#3. 과소적합/오류비 계산 function
def under_est(m) :
    error_sum = np.sum(m) - sum(np.diag(m))
    under_sum = 0
    for i in range(8) :
        under_sum += np.sum(m[i,(i+1):9])
    return under_sum / error_sum

#4. 3등급 이상 과적합/오류비 function
def over3_est(m) :
    total_sum = np.sum(m)
    error_sum = np.sum(m) - sum(np.diag(m))
    over3C_sum = 0
    for i in range(8) :
        over3C_sum += m[i,i+1] + m[i+1,i]
    for i in range(7) :
        over3C_sum += m[i,i+2] + m[i+2,i]
    diag_sum = sum(np.diag(m))
    return (total_sum - (over3C_sum + diag_sum)) / error_sum

#전체 performance 지표를 출력하는 function
def eval_stat(m) :
    print("정확도 : ",round(acc(m) * 100,2),"%")
    print("근접정확도 : ",round(nearest_acc(m) * 100,2),"%")
    print("과소적합/오류 비 : ",round(under_est(m) * 100,2),"%")
    print("3등급이상과적합/오류 비 : ",round(over3_est(m) * 100,2),"%")
    

#multinomial logistic regression에서 전체 summary에 대한 회귀계수 값을 가져오는 function  
#arg 설명
##cmodel = model.fit (이때 model은 MNLogit 모형)
def check_beta(cmodel) :
    a = cmodel.summary()
    b = a.tables[1]
    b = pd.DataFrame(b)
    b = b.transpose()
    b = b[0:2]
    k = b.shape[1]/8
    ind=[]
    m_table = pd.DataFrame(index=range(0,8), columns=b.loc[0,1:(k-1)])
    for i in range(8) : 
        coeff = b.loc[1,(i*k):((i+1)*k-1)]
        m_table.iloc[i] = coeff[1:].tolist()
        ind.append(b.loc[0,(i*k)])
    m_table.index=ind
    return m_table

#multinomial logistic regression에서 marginal summary에 대한 회귀계수 값을 가져오는 function 
def check_beta_mar(cmodel) :
    a = cmodel.summary()
    b = a.tables[1]
    b = pd.DataFrame(b)
    b = b.transpose()
    b = b[0:2]
    k = b.shape[1]/9
    ind=[]
    m_table = pd.DataFrame(index=range(0,9), columns=b.loc[0,1:(k-1)])
    for i in range(9) : 
        coeff = b.loc[1,(i*k):((i+1)*k-1)]
        m_table.iloc[i] = coeff[1:].tolist()
        ind.append(b.loc[0,(i*k)])
    m_table.index=ind
    return m_table

#multinomial logistic regression에서 전체 summary에 대한 p-value 값을 가져오는 function  
def check_p_value(cmodel) :
    a = cmodel.summary()
    b = a.tables[1]
    b = pd.DataFrame(b)
    b = b.transpose()
    b = b.loc[[0,4],:]
    b.reset_index(drop=True, inplace=True)
    k = b.shape[1]/8
    m_table = pd.DataFrame(index=range(0,8), columns=b.loc[0,1:(k-1)])
    ind=[]
    for i in range(8) : 
        coeff = b.loc[1,(i*k):((i+1)*k-1)]
        m_table.iloc[i] = coeff[1:].tolist()
        ind.append(b.loc[0,(i*k)])
    m_table.index=ind
    return m_table

#multinomial logistic regression에서 marginal summary에 대한 p-value 값을 가져오는 function  
def check_p_value_mar(cmodel) :
    a = cmodel.summary()
    b = a.tables[1]
    b = pd.DataFrame(b)
    b = b.transpose()
    b = b.loc[[0,4],:]
    b.reset_index(drop=True, inplace=True)
    k = b.shape[1]/9
    m_table = pd.DataFrame(index=range(0,9), columns=b.loc[0,1:(k-1)])
    ind=[]
    for i in range(9) : 
        coeff = b.loc[1,(i*k):((i+1)*k-1)]
        m_table.iloc[i] = coeff[1:].tolist()
        ind.append(b.loc[0,(i*k)])
    m_table.index=ind
    return m_table

#confusion matrix를 만들어주는 function
#arg 설명
## real : 참값 , pred : 예측값
def make_confusionmatrix(real, pred) :
    mat = pd.DataFrame(index=range(0,9))
    for i in range(0,9):
        b = pd.Series(np.array([0]*9))
        mat = pd.concat([b,mat], axis=1)

    real.reset_index(drop=True, inplace=True)
    pred = pd.Series(pred)
    pred_mat = pd.concat([real,pred],axis=1)
    pred_mat.columns=['real','pred']
    pred_mat = pd.crosstab(pred_mat.real, pred_mat.pred)
    real_ind = pred_mat.index.astype('int')-1
    pred_ind = pred_mat.columns.astype('int')-1

    for i in range(pred_mat.shape[0]):
        for j in range(pred_mat.shape[1]):
            mat.iloc[real_ind[i],pred_ind[j]] = pred_mat.iloc[i,j]
    mat = np.array(mat)
    return(mat)

# %% [markdown]
# #### 데이터 불러오기 및 정보 확인

# %%
df = pd.read_excel("S_final.xlsx")
data = copy.deepcopy(df)

# %% [markdown]
# #### 변수들의 type을 알맞게 변환
# * object type으로 변경해야 할 변수 존재<br>
# * 종목코드, 가족친화인증, 고용관련인증, 지가경발간, 지가경공시, ESG채권, 소비자중심경영, 지역사회공헌, 정보보호공시, 기부_투자

# %%
## object에 해당하는 변수들 변경
chang_var = ['종목코드', '가족친화인증', '고용관련인증', '지가경발간', '지가경공시', 'ESG채권', '소비자중심경영',
            '지역사회공헌', '정보보호공시', '기부_투자']
data[chang_var]=data[chang_var].astype('object')

## preprocessing을 위한 train and test set 분리
print(data['S_GRADE'].unique())
train = data.loc[data['S_GRADE']!=0,]
test = data.loc[data['S_GRADE']==0,]

# index 초기화 하기
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)
#print(train.shape, test.shape)
# Out:
# [2 1 3 4 5 6 7 8 9 0]

# %% [markdown]
# ## 1. Preprocessing

# %% [markdown]
# #### num_var과 categ_var 이름 할당

# %%
# 그래프에서의 한글 깨짐 제거
if platform.system() == 'Windows':
    matplotlib.rc('font', family='Malgun Gothic')
elif platform.system() == 'Darwin': # Mac
    matplotlib.rc('font', family='AppleGothic')
else: #linux
    matplotlib.rc('font', family='NanumGothic')

# categorical variable과 numeric variable의 colname을 저장
categ_var= [var for var in train.columns if train[var].dtype=='object']
num_var= [var for var in train.columns if train[var].dtype!='object']
categ_var = categ_var[3:-1] # 가족친화인증 ~ 기부_투자
num_var = num_var[1:] # 여성임원비율 ~ S_risk

# %% [markdown]
# #### 변수간의 관계 - plot

# %%
# 산점도 행렬 출력
# print(num_var)
plt.figure(figsize = (15,8))
scatter_matrix(train.drop(columns=['S_GRADE'], inplace=False), alpha=0.5, figsize=(8,8), 
               diagonal='kde')
plt.show()

# 산점도 행렬을 S_GRADE의 범주에 따라 그림
p_data = train[num_var]
p_data['S_GRADE'] = train['S_GRADE'].astype('object')
sns.pairplot(p_data, diag_kind='auto', hue='S_GRADE')
plt.show()

# 상관계수 행렬 그래프 : 연속 vs. 연속
p_data = p_data.drop(columns='S_GRADE').corr(method='pearson')
plt.figure(figsize = (15,8))
sns.heatmap(p_data, xticklabels=p_data.columns, yticklabels=p_data.columns,
           annot=True,cmap='gist_heat_r')
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21316\910031100.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_data['S_GRADE'] = train['S_GRADE'].astype('object')
# C:\Users\user\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\user\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# * 첫 번째 plot을 봤을 때, 대부분의 변수들이 G data와 같이 왼쪽으로 치우치거나 bimodal인 경우가 많아 보인다. 또한 S data에서는 G data에서와 달리 오른쪽으로 치우친 분포도 존재한다. 정규직비율, 여성평균근속연수대비총합이 그런 경우에 속한다. 따라서 모형에 잘못된 정보를 줄 가능성이 높아 보인다.
# * 두 번째 plot을 보면 대부분의 그래프들이 bimodal의 경향을 보이기는 하지만 첫 번째 plot 보다는 조금 더 정규분포에 모습에 가깝다. 이는 각 등급에 따라 해당 x 변수들의 분포가 달라진다고 해석할 수 있다. 따라서 해당 설명변수를 사용하더라도 모형에 잘못된 정보를 주지는 않을 것이라고 판단한다.
# * 세 번째 plot은 x변수들의 correlation값을 heatmap으로 나타낸 것이다. 대부분 유의미한 상관계수를 가지고 있지 않지만 여성직원비율과 업종별여성비율의 경우 상관계수가 0.65로 가장 높은 상관관계를 가지고 있다. 추후 모델링에 있어 다중공선성이 우려된다.

# %% [markdown]
# #### 데이터의 정규성 검정 및 수치 확인

# %%
# 연속형 데이터의 정규성을 검정하기 위해 shapiro test 진행
## p-value가 굉장히 작음 -> H0(정규성 충족) 기각
## 따라서 해당 데이터의 연속형 변수들은 정규성을 만족하지 못하므로 transformation이 필요.
for var in num_var :
    shapiro_test = shapiro(train[var])
    print(var, shapiro_test)

print(' ')

# 왜도 : 분포의 비대칭도
print("왜도는")
pd.DataFrame(skew(train[num_var]), index=num_var).T
# Out:
# 여성임원비율 ShapiroResult(statistic=0.6173595190048218, pvalue=8.35901681044643e-36)
# ESG임원비율 ShapiroResult(statistic=0.3075653314590454, pvalue=4.203895392974451e-44)
# 미등기여성임원비율21 ShapiroResult(statistic=0.438193142414093, pvalue=4.5015311867970424e-41)
# 여성직원비율 ShapiroResult(statistic=0.9148173332214355, pvalue=8.198810021411886e-19)
# 업종별여성비율 ShapiroResult(statistic=0.839423418045044, pvalue=2.786664213201967e-25)
# 정규직비율 ShapiroResult(statistic=0.6248328685760498, pvalue=1.522518736380036e-35)
# 인력유지율 ShapiroResult(statistic=0.10261708498001099, pvalue=0.0)
# 여성평균급여대비총합 ShapiroResult(statistic=0.8546510934829712, pvalue=3.38433713456026e-24)
# 여성평균근속연수대비총합 ShapiroResult(statistic=0.9504765868186951, pvalue=4.334240147232764e-14)
# 공정위위반횟수 ShapiroResult(statistic=0.21731382608413696, pvalue=0.0)
# 잡플래닛평점 ShapiroResult(statistic=0.99260413646698, pvalue=0.0023123749997466803)
# 신규채용률 ShapiroResult(statistic=0.3779696226119995, pvalue=1.5596451907935214e-42)
# S_risk ShapiroResult(statistic=0.913421630859375, pvalue=5.763648200698652e-19)
#
# 왜도는
#      여성임원비율   ESG임원비율  미등기여성임원비율21    여성직원비율  업종별여성비율     정규직비율      인력유지율  \
# 0  1.910255  3.822895     4.462828  0.861377  2.32754 -3.390951  17.580357
#
#    여성평균급여대비총합  여성평균근속연수대비총합   공정위위반횟수    잡플래닛평점      신규채용률    S_risk
# 0   -1.449264     -0.653812  7.413454  0.138511  10.938584  0.969876

# %%
# 첨도 : 분포의 뾰족한 정도
# 0 (정규분포) / 첨도>0 (위로 뾰족) / 첨도<0 (아래로 뾰족)
print("첨도는")
pd.DataFrame(kurtosis(train[num_var], fisher=True), index=num_var).T
# Out:
# 첨도는
#      여성임원비율    ESG임원비율  미등기여성임원비율21    여성직원비율    업종별여성비율      정규직비율  \
# 0  3.802749  14.563492    27.762584 -0.049704  10.998156  16.049176
#
#         인력유지율  여성평균급여대비총합  여성평균근속연수대비총합    공정위위반횟수    잡플래닛평점       신규채용률  \
# 0  327.213127   11.085461      2.959893  71.467887  0.378797  158.258041
#
#      S_risk
# 0  0.406305

# %% [markdown]
# raw data에 대한 plot과 더 정확한 정규성 검정을 위한 shapiro test, 왜도, 첨도값을 출력했다. 각 값들의 의미는 G_FinalModeling에 있으므로 생략한다.
# plot에서 볼 수 있듯이 shapiro test 결과 S_data에 사용된 numeric variable은 모두 정규성을 만족하지 않는다. 또한 대부분의 변수들의 왜도가 0보다 크고, 그 값 또한 0과 멀다. 즉, 대부분의 변수들이 왼쪽으로 치우친 모습을 보인다. 다만 정규직비율, 여성평균급여대비총합, 여성평균근속연수대비총합의 경우는 오른쪽으로 치우친 모습을 보인다. 첨도는 여성직원비율을 제외하고는 대부분 0보다 큰 값으로 정규분포보다 뾰족한 분포를 따른다고 할 수 있다. 특히 인력유지율, 공정위위반횟수, 신규채용률의 경우는 첨도가 아주 심하게 큰 것을 알 수 있다.

# %% [markdown]
# #### 데이터 Scaling using Quantile Transformation
# - 위 결과를 통해서 해당 변수들에게 scaling을 해줘야 한다는 insight를 얻을 수 있었다. Quantile Transformation에 대한 자세한 설명은 G_FinalModeling에 있으므로 생략하도록 하겠다.

# %%
qt = QuantileTransformer(output_distribution='normal')
qt.fit(train[num_var])
train[num_var] = qt.transform(train[num_var])
test[num_var] = qt.transform(test[num_var])
scatter_matrix(train[num_var], alpha=0.5, figsize=(8,8), diagonal='kde')
plt.show()


# 상관계수 행렬 그래프 : 연속 vs. 연속
train_corr = train[num_var].corr(method='pearson')
sns.heatmap(train_corr, xticklabels=num_var, yticklabels=num_var,
           annot=True,cmap='gist_heat_r')
plt.show()

print("정규성 검정")
for var in num_var :
    shapiro_test = shapiro(train[var])
    print(var, shapiro_test)

print("왜도는")
pd.DataFrame(skew(train[num_var]), index=num_var).T
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2590: UserWarning: n_quantiles (1000) is greater than the total number of samples (661). n_quantiles is set to n_samples.
#   warnings.warn(
# C:\Users\user\AppData\Local\Temp\ipykernel_21316\3980708425.py:6: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.savefig('S4.png', dpi=500)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 정규성 검정
# 여성임원비율 ShapiroResult(statistic=0.597968578338623, pvalue=1.841332010856104e-36)
# ESG임원비율 ShapiroResult(statistic=0.3152739405632019, pvalue=6.165713243029195e-44)
# 미등기여성임원비율21 ShapiroResult(statistic=0.5632219314575195, pvalue=1.4104970358601538e-37)
# 여성직원비율 ShapiroResult(statistic=0.9761202335357666, pvalue=6.555689324727609e-09)
# 업종별여성비율 ShapiroResult(statistic=0.9761214852333069, pvalue=6.560757714879628e-09)
# 정규직비율 ShapiroResult(statistic=0.7607220411300659, pvalue=7.088142914441404e-30)
# 인력유지율 ShapiroResult(statistic=0.9905295372009277, pvalue=0.0002975753741338849)
# 여성평균급여대비총합 ShapiroResult(statistic=0.9684205651283264, pvalue=9.780439652606887e-11)
# 여성평균근속연수대비총합 ShapiroResult(statistic=0.9607436060905457, pvalue=2.7058173410199338e-12)
# 공정위위반횟수 ShapiroResult(statistic=0.27890968322753906, pvalue=1.1210387714598537e-44)
# 잡플래닛평점 ShapiroResult(statistic=0.9801359176635742, pvalue=8.18163385929438e-08)
# 신규채용률 ShapiroResult(statistic=0.7859347462654114, pvalue=1.4927647072527278e-28)
# S_risk ShapiroResult(statistic=0.7784243226051331, pvalue=5.854653095389095e-29)
# 왜도는
#      여성임원비율   ESG임원비율  미등기여성임원비율21    여성직원비율   업종별여성비율     정규직비율     인력유지율  \
# 0  1.032043  3.064612     1.245182 -0.279493 -0.279479  1.134279 -0.000127
#
#    여성평균급여대비총합  여성평균근속연수대비총합   공정위위반횟수    잡플래닛평점     신규채용률    S_risk
# 0   -0.407676     -0.526645  3.511085 -0.135029 -1.738586 -1.652408

# %%
print("첨도는")
pd.DataFrame(kurtosis(train[num_var], fisher=True), index=num_var).T
# Out:
# 첨도는
#      여성임원비율   ESG임원비율  미등기여성임원비율21    여성직원비율   업종별여성비율     정규직비율     인력유지율  \
# 0 -0.826055  7.549263    -0.337313  2.573219  2.573184 -0.100129  1.415681
#
#    여성평균급여대비총합  여성평균근속연수대비총합    공정위위반횟수    잡플래닛평점     신규채용률    S_risk
# 0    3.054799      3.474538  10.640785  2.058893  3.560765  2.597953

# %%
## dummy variable을 위해 scaling한 데이터를 다시 합침
total_data = pd.concat([train, test], ignore_index=True)

# %% [markdown]
# * Scaling을 한 결과 첫 번째 plot과 같이 scaling 전보다는 정규분포의 모양을 띄는 것을 보인다. 특히 오른쪽으로 쏠려있었던 정규직비율, 여성평균급여대비총합, 여성평균근속연수대비총합의 경우는 sacling이 잘 되었고, 왼쪽으로 많이 치우친 변수들의 경우에는 plot으로 봤을 때는 여전히 쏠려 있는 분포이다.
#
# * 두 번째 plot은 상관계수에 관련된 것이다. scaling 하기 전 문제가 되었던 업종별여성비율과 여성직원비율의 상관계수가 오히려 0.81로 커진 것을 알 수 있다. 이는 이름에서도 알 수 있듯이 두 변수가 관계가 많기 때문인 것으로 추후 모델링에서 variable selection을 통해 괜찮아 질 것으로 보인다.
#
# * 더 자세한 정보를 위해 test와 첨도, 왜도를 출력했다. 왜도의 경우 대부분 안정화 되었고, 0보다 훨씬 컸던 인력유지율(17),공정위위반횟수(7), 신규채용률(11)의 경우 많이 줄어들었다. 그리고 300대에 육박해 심각하던 인력유지율의 첨도가 1.415로 안정화 되었고, 그 외 공정위위반횟수나 신규채용률의 경우도 첨도가 아직 크긴 하지만 그 전 값에 비해서는 훨씬 안정화된 모습이다. 정규성을 가설검정으로 보장하지는 않지만 첨도와 왜도가 어느 정도 줄어들었고, 더 이상의 변환은 데이터에 불필요한 보정을 할 수 있어 하지 않았다.
#
# * Social data도 G data와 마찬가지로 정규성을 가설검정으로 보장하지는 않지만 첨도와 왜도가 굉장히 줄어들었고, 더 이상의 변환은 데이터에 불필요한 보정을 할 수 있어 하지 않았다.

# %% [markdown]
# ####  object type 변수들에 대해서 dummy variable 생성
# - 자세한 설명은 G_FinalModeling에 있으므로 생략한다.

# %%
# linear regression용 data의 경우 multicollinearity를 예방하기 위해 categorical variable에서 
# category의 개수가 3이상인 경우, 마지막 변수를 제거. : 없음
print("The value counts are")   
print("Variables have more than three levels")
for var in categ_var :
    if len(total_data[var].unique()) >= 3 :
        print(var, end=', ')
        
# regression용 data
rdata = copy.deepcopy(total_data)
# rdata = pd.get_dummies(rdata, columns=['이사회독립성'])
# print(rdata.columns)
# rdata.drop(columns=['이사회독립성_겸임'], inplace=True)

# binary variable들을 다시 int type으로 변경
chan_var = [var for var in rdata.columns if rdata[var].dtype == 'object']
chan_var = chan_var[3:-1]
rdata[chan_var] = rdata[chan_var].astype('int')

## machinelearning용 data -> object를 factor화
mdata = copy.deepcopy(total_data)
object_columns = mdata.dtypes[mdata.dtypes == 'object'].index.tolist()

for column in object_columns[3:-1]:
    mdata[column] = pd.factorize(mdata[column])[0]
# Out:
# The value counts are
# Variables have more than three levels
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\algorithms.py:798: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   uniques = Index(uniques)

# %% [markdown]
# #### rdata와 mdata를 train과 test set으로 분리.

# %%
r_train = rdata.loc[rdata['S_GRADE']!=0,]
r_test = rdata.loc[rdata['S_GRADE']==0,]
m_train = mdata.loc[rdata['S_GRADE']!=0,]
m_test = mdata.loc[rdata['S_GRADE']==0,]

# index를 reset
r_train = r_train.reset_index(drop=True)
r_test = r_test.reset_index(drop=True)
m_train = m_train.reset_index(drop=True)
m_test = m_test.reset_index(drop=True)

# print(r_train.shape, r_test.shape, m_train.shape, m_test.shape)

# %% [markdown]
# ## 2. Model Selection
# - 머신러닝에서 2개의 모델, 회귀분석에서 2개의 모델 총 4개의 모델을 이용하여 당사에서 제공한 참값이 입력되어 있는 train set을 이용하여 다시 train과 test로 나누어서 hyperparameter tuning 및 예측 결과를 비교하려 한다. 이때 분석 데이터는 업종별, 등급별로 층을 나누어 분포한 데이터라고 생각되어 층화추출을 이용하여 train과 test set을 나누었다.

# %% [markdown]
# ### 2-1. RandomForest : m_train 사용
#     * 목차
#         - hyper parameter setting (using cross validation)
#         - modeling (using k-fold)
#         - performance check
#
# - 특징
#     - 데이터가 적더라도 반복 학습, 검증을 통해 overfitting을 방지
#     - 상대적으로 튜닝이 거의 필요 없음
#     - variable importance를 통해 어느 정도 변수에 대한 설명 가능

# %% [markdown]
# #### hyper parameter tuning
# - 머신러닝에서 hyperparameter를 tuning하기 위해 여러가지 parameter 선택 값과 cross validation을 사용하였다. 이때 cross-validation의 값은 5를 사용했다.

# %%
## parameter tuning
# n_estimator : 트리의 개수. default는 10, 많을수록 성능이 좋아질 수 있으나 항상 그런 건 아님.
# max_depth : 트리의 깊이
# min_samples_leaf : leaf node가 되기 위한 최소한의 샘플 데이터 수
# min_samples_split : 노드를 분할하기 위한 최소한의 데이터 수

n_estimators = [50,100,200,300,400,500,700]
max_depth = [6,8,10,12]
min_samples_leaf = [3,5,7,10]
min_samples_split = [3,5,7,10]

## K-Fold
y = m_train['S_GRADE'] 
new_data = m_train.drop(columns=['종목코드','회사명','SICS_Sector_Kr','S_GRADE','Stratify'], 
                     inplace=False)
new_data = np.array(new_data)

# split 개수, 셔플 여부 및 seed 설정
str_kf = StratifiedKFold(n_splits = 5)

# split 개수 스텝 만큼 train, test 데이터셋을 매번 분할
best_hype = []
acc_vec = []
nearest_acc_vec = []
under_est_vec = []
over3_est_vec = []

for train_index, test_index in str_kf.split(new_data, m_train['Stratify']):
    x_train, x_test = new_data[train_index], new_data[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    
    for i in range(len(n_estimators)) :
        print(i, end='')
        for j in range(len(max_depth)) :
            for k in range(len(min_samples_leaf)) :
                for l in range(len(min_samples_split)) :
                    model = RandomForestClassifier(max_depth=max_depth[j], 
                                                   min_samples_leaf=min_samples_leaf[k],
                                                   min_samples_split=min_samples_split[l],
                                                   n_estimators=n_estimators[i], 
                                                   random_state=10)
                    model.fit(x_train, y_train)
                    y_pred = model.predict(x_test) # 예측 라벨
                    m = make_confusionmatrix(y_test, y_pred)
                    acc_vec.append(acc(m))
                    nearest_acc_vec.append(nearest_acc(m))
                    under_est_vec.append(under_est(m))
                    over3_est_vec.append(over3_est(m))
                    hype = [n_estimators[i],max_depth[j],min_samples_leaf[k],min_samples_split[l]]
                    best_hype.append(hype)
                    
# hyperparameter들의 결과를 출력 및 저장
hype = pd.DataFrame(best_hype, columns=['ne', 'md', 'ml', 'ms'])
rf_hype = pd.DataFrame({'정확도':acc_vec, '근접정확도':nearest_acc_vec,
                       '과소추정오류비':under_est_vec, '3단계과추정률':over3_est_vec})

rf_hype = pd.concat([hype, rf_hype], axis=1)
rf_hype_mean = rf_hype.groupby(['ne', 'md', 'ml', 'ms'], as_index=False).mean()
print(rf_hype_mean.sort_values('정확도',ascending=False).head(1))
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# 01234560123456012345601234560123456      ne  md  ml  ms       정확도     근접정확도   과소추정오류비   3단계과추정률
# 211  300   8   3  10  0.378309  0.750444  0.656312  0.204368

# %% [markdown]
# * 위의 값이 가장 accuracy가 좋았던 hyperparameter 값이다. 이에 따라 해당 값으로 random forest 모형 fitting을 진행했다.

# %% [markdown]
# #### K-fold를 활용한 fitting 및 performance 출력

# %%
## set hyperparameter 
sel = rf_hype_mean.sort_values('정확도',ascending=False).head(1)
ne=sel.iloc[0,0] #n_estimators
md=sel.iloc[0,1] #max_depth
ml=sel.iloc[0,2] #min_samples_leaf
ms=sel.iloc[0,3] #min_samples_split


## K-Fold를 통한 randomforest fitting
y = m_train['S_GRADE'] 
new_data = m_train.drop(columns=['종목코드','회사명','SICS_Sector_Kr','S_GRADE','Stratify'], 
                     inplace=False)
new_data = np.array(new_data)

# split 개수, 셔플 여부 및 seed 설정 / 5-fold 진행
str_kf = StratifiedKFold(n_splits = 5)

# split 개수 스텝 만큼 train, test 데이터셋을 매번 분할
acc_vec = []
nearest_acc_vec = []
under_est_vec = []
over3_est_vec = []
start = time.time() 
for train_index, test_index in str_kf.split(new_data, m_train['Stratify']):
    x_train, x_test = new_data[train_index], new_data[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    # hyper parameter tuning의 결과
    model = RandomForestClassifier(n_estimators=ne, max_depth=md, min_samples_leaf=ml,
                                  min_samples_split=ms)
    model.fit(x_train, y_train) # 모델 학습

    y_pred = model.predict(x_test) # 예측 라벨
    m = make_confusionmatrix(y_test, y_pred)
    acc_vec.append(acc(m))
    nearest_acc_vec.append(nearest_acc(m))
    under_est_vec.append(under_est(m))
    over3_est_vec.append(over3_est(m))
    
print("time :", time.time() - start)
print("정확도:",np.round(acc_vec,4)*100,"   ", "정확도 평균:",np.round(st.mean(acc_vec),4)*100)
print("근접정확도:",np.round(nearest_acc_vec,4)*100,"   ", "근접정확도 평균:",np.round(st.mean(nearest_acc_vec),4)*100)
print("과소추정오류비:",np.round(under_est_vec,4)*100,"   ", "과소추정오류비 평균:",np.round(st.mean(under_est_vec),4)*100)
print("3단계과추정률:",np.round(over3_est_vec,4)*100,"   ", "3단계과추정률:",np.round(st.mean(over3_est_vec),4)*100)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# time : 1.6028833389282227
# 정확도: [28.57 36.36 41.67 40.15 34.09]     정확도 평균: 36.17
# 근접정확도: [74.44 76.52 78.79 75.   71.21]     근접정확도 평균: 75.19
# 과소추정오류비: [76.84 71.43 51.95 70.89 56.32]     과소추정오류비 평균: 65.49000000000001
# 3단계과추정률: [13.68 21.43 20.78 26.58 19.54]     3단계과추정률: 20.4

# %% [markdown]
# * Random Forest의 결과는 위와 같다. 소요시간은 1.602초 이다.
# * 각 정확도와 근접정확도, 과소추정오류비, 그리고 3단계과추정률은 위의 값과 같다.
# * 정확도는 28%-41%이다. 근접정확도는 약 51%-79%이다. 과소추정오류비는 51%-76%이다. 3단계과추정률은 13%-26%이다.
# * 각 지표의 평균 값은 각 정확도, 근접정확도, 과소추정오류비, 3단계과추정률 순으로 36.17%, 75.19%, 65.49%, 20.4%이다.

# %% [markdown]
# ### 2-2. XBART : m_train 사용 sleep
#      * 목차
#     - hyper parameter setting (using cross validation)
#     - modeling (using k-fold)
#     - performance check
#
# - 특징 및 설명
#     - Bayesian Additive Regression Tree 방식
#     - Bayesian방식으로 additive regression tree를 사용한 모델로 prior를 선택할 수 있는 것이 큰 특징
#     - tree 모형과 마찬가지로 예측에 있어서 logic을 가지고 있기 때문에 classification에 대한 논리 설명 가능
#     - variable importance를 통해 어느 정도 변수에 대한 설명 가능
#     - 속도가 느리고 mcmc mixing이 다소 느릴 수 있다는 게 단점

# %% [markdown]
# #### hyper parameter tuning

# %%
## parameter tuning
# parameter에 대한 설명
# num_trees : 각 반복에서의 트리의 개수, default=100
# num_sweeps : MCMC 반복 수, default=40
# n_min : 각 final node에서 sample의 최소 개수
# alpha, beta : tree prior hyperparameter : alpha*(1+depth)^beta : default(0.95 / 1.25)
# kap. s : prior for sigma : default(16.0 / 4.0)

num_trees = [100,200]
num_sweeps = [100,200]
n_min = [5,7,10]


## K-Fold
y = m_train['S_GRADE'] 
new_data = m_train.drop(columns=['종목코드','회사명','SICS_Sector_Kr','S_GRADE','Stratify'], 
                     inplace=False)
new_data = np.array(new_data)


# split 개수, 셔플 여부 및 seed 설정
str_kf = StratifiedKFold(n_splits = 5)

# split 개수 스텝 만큼 train, test 데이터셋을 매번 분할
best_hype = []
acc_vec = []
nearest_acc_vec = []
under_est_vec = []
over3_est_vec = []
for train_index, test_index in str_kf.split(new_data, m_train['Stratify']):
    x_train, x_test = new_data[train_index], new_data[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    # multicalss classification에 사용되는 newton-cg와 lbfgs 중 더 성능이 좋다고 
    # 알려진 lbfgs 사용
    for i in range(len(num_trees)) :
        print(i, end='')
        for j in range(len(num_sweeps)) :
            for k in range(len(n_min)) :
                model = XBART(model='Multinomial', num_classes=9, seed=10, num_trees=num_trees[i], 
                              num_sweeps=num_sweeps[j],n_min=n_min[k])
                model.fit(x_train, y_train)
                y_pred = model.predict(x_test, return_mean=True)
                y_pred = y_pred.argmax(1) + 1
                m = make_confusionmatrix(y_test, y_pred)
                acc_vec.append(acc(m))
                nearest_acc_vec.append(nearest_acc(m))
                under_est_vec.append(under_est(m))
                over3_est_vec.append(over3_est(m))
                hype = [num_trees[i],num_sweeps[j],n_min[k]]
                best_hype.append(hype)

                
# hyperparameter들의 결과를 출력 및 저장
hype = pd.DataFrame(best_hype, columns=['nt', 'ns', 'nm'])
bart_hype = pd.DataFrame({'정확도':acc_vec, '근접정확도':nearest_acc_vec,
                       '과소추정오류비':under_est_vec, '3단계과추정률':over3_est_vec})

bart_hype = pd.concat([hype, bart_hype], axis=1)
bart_hype_mean = bart_hype.groupby(['nt', 'ns', 'nm'], as_index=False).mean()
print(bart_hype_mean.sort_values('정확도',ascending=False).head(1))
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# 0101010101

# %% [markdown]
# * 위의 값이 가장 accuracy가 좋았던 hyperparameter 값이다. 이에 따라 해당 값으로 bart 모형 fitting을 진행했다.

# %% [markdown]
# #### K-fold를 활용한 fitting 및 performance 출력

# %%
sel = bart_hype_mean.sort_values('정확도',ascending=False).head(1)
nt = sel.iloc[0,0] #num_trees
ns = sel.iloc[0,1] #num_sweeps
nm = sel.iloc[0,2] #n_min

## K-Fold
y = m_train['S_GRADE'] 
new_data = m_train.drop(columns=['종목코드','회사명','SICS_Sector_Kr','S_GRADE','Stratify'], 
                     inplace=False)
new_data = np.array(new_data)


# split 개수, 셔플 여부 및 seed 설정
str_kf = StratifiedKFold(n_splits = 5)

# split 개수 스텝 만큼 train, test 데이터셋을 매번 분할
acc_vec = []
nearest_acc_vec = []
under_est_vec = []
over3_est_vec = []
start = time.time() 
for train_index, test_index in str_kf.split(new_data, m_train['Stratify']):
    x_train, x_test = new_data[train_index], new_data[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    
    model = XBART(model='Multinomial', num_classes=9, seed=10, num_trees=nt, 
                              num_sweeps=ns,n_min=nm)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test, return_mean=True)
    y_pred = y_pred.argmax(1) + 1
    m = make_confusionmatrix(y_test, y_pred)
    acc_vec.append(acc(m))
    nearest_acc_vec.append(nearest_acc(m))
    under_est_vec.append(under_est(m))
    over3_est_vec.append(over3_est(m))

print("time :", time.time() - start)
print("정확도:",np.round(acc_vec,4)*100,"   ", "정확도 평균:",np.round(st.mean(acc_vec),4)*100)
print("근접정확도:",np.round(nearest_acc_vec,4)*100,"   ", "근접정확도 평균:",np.round(st.mean(nearest_acc_vec),4)*100)
print("과소추정오류비:",np.round(under_est_vec,4)*100,"   ", "과소추정오류비 평균:",np.round(st.mean(under_est_vec),4)*100)
print("3단계과추정률:",np.round(over3_est_vec,4)*100,"   ", "3단계과추정률:",np.round(st.mean(over3_est_vec),4)*100)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# time : 310.190580368042
# 정확도: [10.53 19.7  27.27 27.27 38.64]     정확도 평균: 24.68
# 근접정확도: [33.83 47.73 57.58 54.55 62.88]     근접정확도 평균: 51.31
# 과소추정오류비: [100. 100. 100. 100. 100.]     과소추정오류비 평균: 100.0
# 3단계과추정률: [38.66 42.45 46.88 46.88 55.56]     3단계과추정률: 46.08

# %% [markdown]
# * XBART의 결과는 위와 같다. 소요시간은 310.19초 이다.
# * 각 정확도와 근접정확도, 과소추정오류비, 그리고 3단계과추정률은 위의 값과 같다.
# * 정확도는 10%-38%이다. 근접정확도는 33%-62%, 과소추정오류비는 100%, 3단계과추정률은 38%-55% 이다.
# * 각 지표의 평균 값을 정확도 24.68%, 근접정확도 51.31%, 과소추정오류비 100%, 3단계과추정률이 46.08%이다.

# %% [markdown]
# ### 2-3. Multinomial Logistic Regression : r_train 사용
#        * 목차
#             - modeling (using k-fold)
#             - performance check
#
# - 특징 및 설명
#     - 독립변수의 선형 결합을 이용하여 사건의 발생 가능성을 예측하는데 사용되는 모델
#     - 종속변수가 범주형 데이터일 때를 대상으로 한 모델
#     - 오즈(성공확률/실패확률)를 logit 변환한 모델
#     - 통계에서 가장 기본적이면서도 powerful한 모형으로 사용자가 쉽게 사용가능
#     - 머신러닝 기법과 달리 hyperparameter tuning이 필요 없음
#     - 다양한 자연스러운 통계적 해석이 가능

# %% [markdown]
# #### K-fold를 활용한 fitting 및 performance 출력

# %%
## K-Fold
y = r_train['S_GRADE'] # y값 할당
new_data = r_train.drop(columns=['종목코드','회사명','SICS_Sector_Kr','S_GRADE','Stratify'], 
                     inplace=False)# x값 할당(fitting에 불필요한 변수 제거)
new_data = sm.add_constant(new_data, prepend=False)# 해당 모형을 돌리기 위해 상수부분 추가
new_data = np.array(new_data)


# split 개수, 셔플 여부 및 seed 설정
str_kf = StratifiedKFold(n_splits = 5)

# split 개수 스텝 만큼 train, test 데이터셋을 매번 분할
acc_vec = []
nearest_acc_vec = []
under_est_vec = []
over3_est_vec = []
start = time.time() 
for train_index, test_index in str_kf.split(new_data, r_train['Stratify']):
    x_train, x_test = new_data[train_index], new_data[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    # 다범주 분류에 사용되는 solver에는 newton-cg, lbfgs가 존재
    # lbfgs가 더 성능이 좋다고 알려져있음.
    # 또한 MNLogit에서는 newton-cg 방법을 지원하지 않음.
    model = sm.MNLogit(y_train, x_train) # 모델 학습
    result= model.fit(method='lbfgs', maxiter=10000)


    y_pred = model.predict(result.params, x_test) # 예측 라벨
    y_pred = y_pred.argmax(1) + 1
    m = make_confusionmatrix(y_test, y_pred)
    acc_vec.append(acc(m))
    nearest_acc_vec.append(nearest_acc(m))
    under_est_vec.append(under_est(m))
    over3_est_vec.append(over3_est(m))
print("time :", time.time() - start)
print("정확도:",np.round(acc_vec,4)*100,"   ", "정확도 평균:",np.round(st.mean(acc_vec),4)*100)
print("근접정확도:",np.round(nearest_acc_vec,4)*100,"   ", "근접정확도 평균:",np.round(st.mean(nearest_acc_vec),4)*100)
print("과소추정오류비:",np.round(under_est_vec,4)*100,"   ", "과소추정오류비 평균:",np.round(st.mean(under_est_vec),4)*100)
print("3단계과추정률:",np.round(over3_est_vec,4)*100,"   ", "3단계과추정률:",np.round(st.mean(over3_est_vec),4)*100)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\USER\anaconda3\lib\site-packages\statsmodels\base\model.py:592: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# C:\Users\USER\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# time : 10.51741647720337
# 정확도: [17.29 29.55 39.39 34.09 28.79]     정확도 평균: 29.82
# 근접정확도: [61.65 69.7  74.24 76.52 74.24]     근접정확도 평균: 71.27
# 과소추정오류비: [60.   59.14 51.25 64.37 51.06]     과소추정오류비 평균: 57.16
# 3단계과추정률: [18.18 22.58 21.25 17.24 15.96]     3단계과추정률: 19.040000000000003

# %% [markdown]
# * Multinomial Logistic Regression의 결과는 위와 같다. 소요시간은 10.51초이다.
# * 정확도는 17%-39%, 근접정확도는 61%-76%, 과소추정오류비는 51%-64%, 3단계과추정률은 15%-22%이다.
# * 각 지표의 평균 값은 정확도는 29.82%, 근접정확도는 71.27%, 과소추정오류비는 57.16%, 3단계과추정률은 19.04% 이다.
#
# * 해당 모형에서 사용할 수 있는 solver에 관련된 설명은 G_FinalModeling에 있으므로 생략한다.

# %% [markdown]
# ### 2-4. Ordinal Logistic Regression : r_train 사용
#      * 목차
#         - modeling (using k-fold)
#         - performance check
#
# - 특징 및 설명
#     - 종속변수가 범주형 데이터이고 순서가 있을 때를 대상으로 한 모델
#     - 머신러닝 기법과 달리 hyperparameter tuning이 필요 없음
#     - 다양한 자연스러운 통계적 해석이 가능

# %% [markdown]
# #### K-fold를 활용한 fitting 및 performance 출력

# %%
## K-Fold
t = pd.CategoricalDtype(categories = [9,8,7,6,5,4,3,2,1], ordered = True)
y = pd.Series(r_train['S_GRADE'], dtype = t)
new_data = r_train.drop(columns=['종목코드','회사명','SICS_Sector_Kr','S_GRADE','Stratify'], 
                     inplace=False)
new_data = np.array(new_data)


# split 개수, 셔플 여부 및 seed 설정
str_kf = StratifiedKFold(n_splits = 5)

# split 개수 스텝 만큼 train, test 데이터셋을 매번 분할
acc_vec = []
nearest_acc_vec = []
under_est_vec = []
over3_est_vec = []
start = time.time() 
for train_index, test_index in str_kf.split(new_data, r_train['Stratify']):
    x_train, x_test = new_data[train_index], new_data[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    
    model = OrderedModel(y_train, x_train, distr = 'probit')
    result = model.fit(method='lbfgs', maxiter=10000) # 모델 학습

    y_pred = model.predict(result.params, exog = x_test) # 예측 라벨
    y_pred = y_pred.argmax(1) + 1
    m = make_confusionmatrix(y_test, y_pred)
    acc_vec.append(acc(m))
    nearest_acc_vec.append(nearest_acc(m))
    under_est_vec.append(under_est(m))
    over3_est_vec.append(over3_est(m))

print("time :", time.time() - start)
print("정확도:",np.round(acc_vec,4)*100,"   ", "정확도 평균:",np.round(st.mean(acc_vec),4)*100)
print("근접정확도:",np.round(nearest_acc_vec,4)*100,"   ", "근접정확도 평균:",np.round(st.mean(nearest_acc_vec),4)*100)
print("과소추정오류비:",np.round(under_est_vec,4)*100,"   ", "과소추정오류비 평균:",np.round(st.mean(under_est_vec),4)*100)
print("3단계과추정률:",np.round(over3_est_vec,4)*100,"   ", "3단계과추정률:",np.round(st.mean(over3_est_vec),4)*100)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# time : 9.887239217758179
# 정확도: [1.5  2.27 1.52 2.27 3.79]     정확도 평균: 2.27
# 근접정확도: [3.76 3.79 3.79 6.06 6.06]     근접정확도 평균: 4.6899999999999995
# 과소추정오류비: [29.01 20.16 19.23 12.4  11.02]     과소추정오류비 평균: 18.360000000000003
# 3단계과추정률: [93.89 95.35 87.69 89.92 93.7 ]     3단계과추정률: 92.11

# %% [markdown]
# * Ordinal Logistic Regression의 결과는 위와 같다. 소요시간은 9.88초이다.
# * 정확도는 1.5%-3%, 근접정확도는 3%-6%, 과소추정오류비는 11%-29%, 3단계과추정률은 87%-95%이다.
# * 각 지표의 평균 값은 정확도는 2.27%, 근접정확도는 4.68%, 과소추정오류비는 18.36%, 3단계과추정률은 92.11% 이다.
#
# * slover에 대한 의미는 Multinomial Logistic Regression과 같다.

# %% [markdown]
# ## 3. Model select based on performance
# - Multinomial Logistic Model을 선택하게 된 논리는 G_FinalModeling에 자세하게 설명되어 있으니 생략하겠다.

# %% [markdown]
# ## 4. Model Fitting
# - 전체 모형은 cross validation 없이 train set(당사에서 제공한 참값이 있는 data set)을 사용해 적합했다.

# %% [markdown]
# #### 가정 검정 (multicollinearity) : VIF
# - 선택한 모형에 fitting하기 전, 문제가 많이 되는 다중공선성에 대해 살펴보기 위해 VIF를 계산했다.
# - VIF값은 10보다 큰 경우 다중공선성이 발생한 것으로 판단한다.

# %%
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(
   r_train[num_var].values, i) for i in range(r_train[num_var].shape[1])]
vif["features"] = r_train[num_var].columns
print("### Train set VIF ###")
vif
# Out:
# ### Train set VIF ###
#     VIF Factor      features
# 0     2.540030        여성임원비율
# 1     5.461404       ESG임원비율
# 2     2.805998   미등기여성임원비율21
# 3     3.579257        여성직원비율
# 4     3.133297       업종별여성비율
# 5     1.215925         정규직비율
# 6     1.049440         인력유지율
# 7     1.161900    여성평균급여대비총합
# 8     1.243254  여성평균근속연수대비총합
# 9     5.097467       공정위위반횟수
# 10    1.152626        잡플래닛평점
# 11    1.165859         신규채용률
# 12    1.284468        S_risk

# %% [markdown]
# - train set의 VIF값은 위와 같다. VIF값은 10이상일 경우 다중공선성이 발생했다고 해석할 수 있는데 모든 VIF 값이 10보다 작으므로 다중공선성의 위험은 없다.

# %%
#correlation map
plt.figure(figsize = (15,8))
sns.heatmap(r_train[num_var].corr(), annot=True,cmap='gist_heat_r')
plt.show()

# %% [markdown]
# - 상관계수 plot의 결과 앞선 preprocessing 단계에서도 언급했던 여성직원비율과 업종별여성직원간의 상관관계 문제가 존재한다.

# %% [markdown]
# #### 주어진 train data set에 대해 Model Fitting : r_train 사용

# %%
y_train = r_train['S_GRADE']
x_train = r_train.drop(columns=['종목코드','회사명','SICS_Sector_Kr','S_GRADE','Stratify'], 
                     inplace=False)

x = sm.add_constant(x_train, prepend=False)
model = sm.MNLogit(y_train, x)#모형 할당
result = model.fit(method='lbfgs', maxiter=100000, full_output=True)#모형 적합
mar=result.get_margeff() # marginal summary
y_pred = model.predict(result.params, x)#모형 예측
y_pred = y_pred.argmax(1) + 1 #이때, 모형이 예측한 값은 확률값이기 때문에 이를 이용하여 classification 진행
y_pred = pd.Series(y_pred)
## 모형 fitting 결과
print("[Logistic Regression Train Set Evaluation]")
eval_stat(make_confusionmatrix(y_train, y_pred))
# Out:
# [Logistic Regression Train Set Evaluation]
# 정확도 :  44.33 %
# 근접정확도 :  77.91 %
# 과소적합/오류 비 :  58.7 %
# 3등급이상과적합/오류 비 :  19.29 %

# %% [markdown]
# - 전체 train set을 이용하여 모형을 적합한 결과 정확도는 44.33%, 근접정확도는 77.91%, 과소적합/오류비는 58.7%, 3등급이상과적합/오류비는 19.29% 로 나타난다.

# %% [markdown]
# #### result confusion matrix

# %%
confmtrx = np.array(make_confusionmatrix(y_train, y_pred))
confmtrx = pd.DataFrame(confmtrx, index=['real S1','real S2','real S3','real S4','real S5','real S6','real S7', 'real S8',
                              'real S9']
             , columns=['pred S1','pred S2','pred S3','pred S4','pred S5','pred S6','pred S7','pred S8','pred S9'])

plt.figure(figsize = (15,8))
ax = sns.heatmap(confmtrx,annot=True,cmap='gist_heat_r')
plt.show()

# %% [markdown]
# #### Result

# %%
print('### print marginal summary ###')
print(mar.summary())

# Pseudo R-squ. : 맥파든 의사결정계수 : 가장 성능이 좋을 때 1이고, 나쁠 때 0
# Log-Likelihood : 모든 covariate을 넣었을 때의 likelihood 값
# LL-Null : 아무 covariate도 없을 때의 likelihood 값
# LLR p-value : 귀무가설 : Saturated model에서 추가적으로 존재하는 설명 변수의 회귀계수들은 모두 0이다.
# -> p-value가 작으므로 기각 : 해당 모형의 설명변수들의 회귀계수들은 모두 0이 아니다.

print("### print model summary ###")
print(result.summary())
# Out:
# ### print marginal summary ###
#        MNLogit Marginal Effects
# =====================================
# Dep. Variable:                S_GRADE
# Method:                          dydx
# At:                           overall
# ================================================================================
#    S_GRADE=1      dy/dx    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율          -0.0010      0.002     -0.536      0.592      -0.005       0.003
# ESG임원비율          0.0052      0.002      2.252      0.024       0.001       0.010
# 미등기여성임원비율21     -0.0014      0.002     -0.798      0.425      -0.005       0.002
# 여성직원비율           0.0036      0.011      0.322      0.748      -0.018       0.025
# 업종별여성비율          0.0173      0.010      1.777      0.076      -0.002       0.036
# 정규직비율            0.0026      0.004      0.582      0.560      -0.006       0.011
# 인력유지율           -0.0080      0.007     -1.080      0.280      -0.022       0.006
# 여성평균급여대비총합       0.0094      0.008      1.147      0.251      -0.007       0.026
# 여성평균근속연수대비총합    -0.0109      0.009     -1.201      0.230      -0.029       0.007
# 가족친화인증           0.0005      0.013      0.040      0.968      -0.026       0.027
# 고용관련인증          -0.0727      1.477     -0.049      0.961      -2.969       2.823
# 지가경발간            0.0250      0.021      1.193      0.233      -0.016       0.066
# 지가경공시            0.0043      0.012      0.353      0.724      -0.019       0.028
# 공정위위반횟수         -0.0021      0.002     -1.038      0.299      -0.006       0.002
# ESG채권           -0.0004      0.049     -0.008      0.993      -0.096       0.095
# 소비자중심경영          0.0024      0.029      0.082      0.935      -0.055       0.060
# 지역사회공헌           0.0061      0.049      0.124      0.901      -0.090       0.102
# 정보보호공시           0.0092      0.015      0.594      0.552      -0.021       0.040
# 잡플래닛평점           0.0060      0.010      0.610      0.542      -0.013       0.025
# 신규채용률            0.0053      0.005      0.965      0.335      -0.005       0.016
# 기부_투자            0.0229      0.022      1.064      0.287      -0.019       0.065
# S_risk           0.0024      0.013      0.183      0.855      -0.023       0.028
# --------------------------------------------------------------------------------
#    S_GRADE=2      dy/dx    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율           0.0002      0.003      0.062      0.951      -0.005       0.005
# ESG임원비율          0.0031      0.014      0.219      0.827      -0.025       0.031
# 미등기여성임원비율21      0.0022      0.002      0.919      0.358      -0.003       0.007
# 여성직원비율           0.0153      0.015      1.048      0.295      -0.013       0.044
# 업종별여성비율         -0.0283      0.014     -2.088      0.037      -0.055      -0.002
# 정규직비율           -0.0167      0.007     -2.357      0.018      -0.031      -0.003
# 인력유지율           -0.0180      0.009     -2.077      0.038      -0.035      -0.001
# 여성평균급여대비총합      -0.0080      0.010     -0.775      0.438      -0.028       0.012
# 여성평균근속연수대비총합    -0.0018      0.010     -0.192      0.848      -0.021       0.017
# 가족친화인증           0.0169      0.017      0.987      0.323      -0.017       0.050
# 고용관련인증           0.1125      4.073      0.028      0.978      -7.870       8.095
# 지가경발간            0.0549      0.025      2.179      0.029       0.006       0.104
# 지가경공시            0.0336      0.046      0.730      0.465      -0.057       0.124
# 공정위위반횟수         -0.0021      0.003     -0.706      0.480      -0.008       0.004
# ESG채권            0.0795      0.167      0.476      0.634      -0.248       0.407
# 소비자중심경영          0.0466      0.093      0.498      0.618      -0.137       0.230
# 지역사회공헌           0.0481      0.159      0.302      0.763      -0.264       0.361
# 정보보호공시        5.298e-05      0.020      0.003      0.998      -0.040       0.040
# 잡플래닛평점           0.0169      0.011      1.496      0.135      -0.005       0.039
# 신규채용률           -0.0081      0.006     -1.416      0.157      -0.019       0.003
# 기부_투자           -0.0265      0.030     -0.891      0.373      -0.085       0.032
# S_risk           0.0220      0.016      1.384      0.166      -0.009       0.053
# --------------------------------------------------------------------------------
#    S_GRADE=3      dy/dx    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율           0.0028      0.003      0.937      0.349      -0.003       0.009
# ESG임원비율          0.0051      0.050      0.103      0.918      -0.093       0.103
# 미등기여성임원비율21      0.0011      0.003      0.373      0.709      -0.005       0.007
# 여성직원비율          -0.0029      0.017     -0.169      0.866      -0.036       0.031
# 업종별여성비율         -0.0002      0.015     -0.016      0.987      -0.029       0.029
# 정규직비율           -0.0032      0.007     -0.445      0.656      -0.017       0.011
# 인력유지율            0.0246      0.010      2.413      0.016       0.005       0.045
# 여성평균급여대비총합      -0.0062      0.010     -0.607      0.544      -0.026       0.014
# 여성평균근속연수대비총합     0.0130      0.011      1.197      0.231      -0.008       0.034
# 가족친화인증           0.0305      0.019      1.615      0.106      -0.007       0.068
# 고용관련인증          -0.5102     20.535     -0.025      0.980     -40.758      39.738
# 지가경발간            0.0491      0.028      1.777      0.075      -0.005       0.103
# 지가경공시           -0.0329      0.173     -0.190      0.849      -0.372       0.306
# 공정위위반횟수         -0.0006      0.004     -0.150      0.880      -0.008       0.007
# ESG채권            0.1515      0.389      0.390      0.697      -0.611       0.914
# 소비자중심경영          0.0902      0.229      0.395      0.693      -0.358       0.538
# 지역사회공헌           0.1593      0.334      0.478      0.633      -0.495       0.813
# 정보보호공시           0.0292      0.024      1.217      0.224      -0.018       0.076
# 잡플래닛평점           0.0148      0.011      1.372      0.170      -0.006       0.036
# 신규채용률            0.0143      0.011      1.360      0.174      -0.006       0.035
# 기부_투자            0.0771      0.070      1.099      0.272      -0.060       0.215
# S_risk          -0.0260      0.011     -2.460      0.014      -0.047      -0.005
# --------------------------------------------------------------------------------
#    S_GRADE=4      dy/dx    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율           0.0021      0.003      0.691      0.490      -0.004       0.008
# ESG임원비율          0.0107      0.057      0.187      0.851      -0.101       0.123
# 미등기여성임원비율21     -0.0005      0.003     -0.164      0.869      -0.006       0.005
# 여성직원비율           0.0249      0.016      1.540      0.124      -0.007       0.056
# 업종별여성비율         -0.0146      0.015     -0.974      0.330      -0.044       0.015
# 정규직비율            0.0079      0.005      1.459      0.145      -0.003       0.018
# 인력유지율            0.0025      0.009      0.261      0.794      -0.016       0.021
# 여성평균급여대비총합      -0.0186      0.010     -1.879      0.060      -0.038       0.001
# 여성평균근속연수대비총합     0.0023      0.010      0.227      0.821      -0.018       0.022
# 가족친화인증           0.0262      0.019      1.356      0.175      -0.012       0.064
# 고용관련인증           0.1649      4.168      0.040      0.968      -8.005       8.335
# 지가경발간            0.0206      0.028      0.741      0.458      -0.034       0.075
# 지가경공시           -0.0041      0.195     -0.021      0.983      -0.386       0.378
# 공정위위반횟수          0.0019      0.004      0.507      0.612      -0.005       0.009
# ESG채권            0.1269      0.416      0.305      0.760      -0.689       0.943
# 소비자중심경영          0.0259      0.250      0.104      0.917      -0.464       0.516
# 지역사회공헌           0.1485      0.338      0.439      0.661      -0.514       0.811
# 정보보호공시           0.0194      0.022      0.872      0.383      -0.024       0.063
# 잡플래닛평점          -0.0059      0.011     -0.533      0.594      -0.028       0.016
# 신규채용률           -0.0009      0.008     -0.109      0.913      -0.016       0.014
# 기부_투자            0.0686      0.079      0.865      0.387      -0.087       0.224
# S_risk           0.0037      0.014      0.259      0.796      -0.024       0.032
# --------------------------------------------------------------------------------
#    S_GRADE=5      dy/dx    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율          -0.0047      0.004     -1.245      0.213      -0.012       0.003
# ESG임원비율          0.0231      0.143      0.162      0.871      -0.256       0.303
# 미등기여성임원비율21      0.0030      0.003      0.881      0.378      -0.004       0.010
# 여성직원비율          -0.0005      0.019     -0.024      0.981      -0.038       0.037
# 업종별여성비율         -0.0015      0.018     -0.086      0.931      -0.036       0.033
# 정규직비율           -0.0008      0.006     -0.139      0.889      -0.012       0.011
# 인력유지율           -0.0077      0.011     -0.722      0.471      -0.028       0.013
# 여성평균급여대비총합       0.0226      0.011      2.077      0.038       0.001       0.044
# 여성평균근속연수대비총합    -0.0055      0.010     -0.528      0.597      -0.026       0.015
# 가족친화인증           0.0416      0.021      1.963      0.050     6.5e-05       0.083
# 고용관련인증           0.1268      2.964      0.043      0.966      -5.683       5.937
# 지가경발간            0.0326      0.040      0.817      0.414      -0.046       0.111
# 지가경공시           -0.0955      0.434     -0.220      0.826      -0.945       0.754
# 공정위위반횟수          0.0103      0.004      2.470      0.014       0.002       0.018
# ESG채권           -0.2923      2.303     -0.127      0.899      -4.807       4.222
# 소비자중심경영          0.2385      0.435      0.549      0.583      -0.613       1.090
# 지역사회공헌          -0.2816      2.246     -0.125      0.900      -4.684       4.121
# 정보보호공시           0.0349      0.023      1.496      0.135      -0.011       0.081
# 잡플래닛평점           0.0183      0.011      1.640      0.101      -0.004       0.040
# 신규채용률           -0.0066      0.006     -1.014      0.310      -0.019       0.006
# 기부_투자            0.1147      0.188      0.610      0.542      -0.254       0.483
# S_risk           0.0028      0.011      0.262      0.793      -0.018       0.024
# --------------------------------------------------------------------------------
#    S_GRADE=6      dy/dx    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율          -0.0043      0.004     -1.112      0.266      -0.012       0.003
# ESG임원비율          0.0243      0.175      0.138      0.890      -0.319       0.368
# 미등기여성임원비율21     -0.0040      0.004     -1.066      0.287      -0.011       0.003
# 여성직원비율          -0.0097      0.017     -0.564      0.573      -0.044       0.024
# 업종별여성비율          0.0093      0.016      0.583      0.560      -0.022       0.041
# 정규직비율           -0.0012      0.005     -0.233      0.816      -0.011       0.009
# 인력유지율            0.0023      0.010      0.240      0.811      -0.016       0.021
# 여성평균급여대비총합      -0.0100      0.010     -1.038      0.299      -0.029       0.009
# 여성평균근속연수대비총합     0.0032      0.010      0.327      0.743      -0.016       0.023
# 가족친화인증           0.0482      0.022      2.173      0.030       0.005       0.092
# 고용관련인증           0.1512      2.130      0.071      0.943      -4.023       4.326
# 지가경발간            0.0681      0.044      1.532      0.125      -0.019       0.155
# 지가경공시           -0.0884      0.466     -0.190      0.850      -1.003       0.826
# 공정위위반횟수         -0.0017      0.006     -0.284      0.777      -0.014       0.010
# ESG채권            0.3360      0.854      0.394      0.694      -1.337       2.009
# 소비자중심경영         -0.3156      2.242     -0.141      0.888      -4.710       4.079
# 지역사회공헌           0.2890      0.661      0.437      0.662      -1.006       1.584
# 정보보호공시          -0.0083      0.021     -0.389      0.697      -0.050       0.034
# 잡플래닛평점           0.0138      0.010      1.347      0.178      -0.006       0.034
# 신규채용률            0.0143      0.010      1.424      0.154      -0.005       0.034
# 기부_투자            0.0422      0.231      0.183      0.855      -0.410       0.494
# S_risk           0.0140      0.010      1.395      0.163      -0.006       0.034
# --------------------------------------------------------------------------------
#    S_GRADE=7      dy/dx    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율           0.0012      0.005      0.249      0.803      -0.008       0.011
# ESG임원비율          0.0603      0.521      0.116      0.908      -0.961       1.081
# 미등기여성임원비율21      0.0047      0.005      0.946      0.344      -0.005       0.014
# 여성직원비율          -0.0070      0.025     -0.277      0.782      -0.057       0.043
# 업종별여성비율          0.0396      0.022      1.795      0.073      -0.004       0.083
# 정규직비율            0.0041      0.006      0.724      0.469      -0.007       0.015
# 인력유지율           -0.0063      0.013     -0.470      0.638      -0.032       0.020
# 여성평균급여대비총합       0.0119      0.013      0.933      0.351      -0.013       0.037
# 여성평균근속연수대비총합     0.0246      0.014      1.786      0.074      -0.002       0.052
# 가족친화인증          -0.0585      0.046     -1.263      0.206      -0.149       0.032
# 고용관련인증           0.1424      1.996      0.071      0.943      -3.769       4.054
# 지가경발간           -0.0457      0.131     -0.349      0.727      -0.302       0.211
# 지가경공시           -1.0733      3.972     -0.270      0.787      -8.858       6.711
# 공정위위반횟수         -0.0019      0.010     -0.187      0.852      -0.022       0.018
# ESG채권           -0.0493      4.893     -0.010      0.992      -9.638       9.540
# 소비자중심경영          0.2432      1.391      0.175      0.861      -2.482       2.969
# 지역사회공헌          -0.5603      4.446     -0.126      0.900      -9.274       8.154
# 정보보호공시           0.0294      0.030      0.964      0.335      -0.030       0.089
# 잡플래닛평점           0.0453      0.014      3.348      0.001       0.019       0.072
# 신규채용률            0.0024      0.010      0.250      0.802      -0.017       0.022
# 기부_투자            0.2235      0.679      0.329      0.742      -1.107       1.554
# S_risk           0.0073      0.010      0.699      0.484      -0.013       0.028
# --------------------------------------------------------------------------------
#    S_GRADE=8      dy/dx    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율           0.0036      0.006      0.589      0.556      -0.008       0.015
# ESG임원비율          0.1495      1.308      0.114      0.909      -2.414       2.713
# 미등기여성임원비율21      0.0035      0.007      0.531      0.595      -0.009       0.016
# 여성직원비율           0.0096      0.033      0.294      0.769      -0.055       0.074
# 업종별여성비율         -0.0055      0.029     -0.189      0.850      -0.062       0.051
# 정규직비율            0.0136      0.007      2.049      0.040       0.001       0.027
# 인력유지율            0.0162      0.016      1.028      0.304      -0.015       0.047
# 여성평균급여대비총합       0.0091      0.016      0.572      0.567      -0.022       0.040
# 여성평균근속연수대비총합    -0.0106      0.016     -0.663      0.507      -0.042       0.021
# 가족친화인증          -0.0352      0.062     -0.569      0.570      -0.157       0.086
# 고용관련인증           0.0444      2.298      0.019      0.985      -4.460       4.549
# 지가경발간           -0.1441      0.200     -0.722      0.471      -0.536       0.247
# 지가경공시           -0.1463      2.309     -0.063      0.949      -4.672       4.380
# 공정위위반횟수         -0.0127      0.014     -0.913      0.361      -0.040       0.015
# ESG채권            0.2081      7.364      0.028      0.977     -14.225      14.641
# 소비자중심경영          0.7870      3.347      0.235      0.814      -5.774       7.348
# 지역사회공헌           1.0537      3.696      0.285      0.776      -6.190       8.298
# 정보보호공시          -0.0487      0.040     -1.226      0.220      -0.127       0.029
# 잡플래닛평점          -0.0506      0.016     -3.101      0.002      -0.083      -0.019
# 신규채용률           -0.0083      0.011     -0.729      0.466      -0.031       0.014
# 기부_투자            0.5467      1.698      0.322      0.747      -2.781       3.875
# S_risk          -0.0097      0.012     -0.827      0.408      -0.033       0.013
# --------------------------------------------------------------------------------
#    S_GRADE=9      dy/dx    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율           0.0002      0.006      0.028      0.977      -0.011       0.012
# ESG임원비율         -0.2814      2.269     -0.124      0.901      -4.728       4.165
# 미등기여성임원비율21     -0.0086      0.007     -1.267      0.205      -0.022       0.005
# 여성직원비율          -0.0333      0.031     -1.062      0.288      -0.095       0.028
# 업종별여성비율         -0.0162      0.027     -0.594      0.552      -0.069       0.037
# 정규직비율           -0.0064      0.006     -1.017      0.309      -0.019       0.006
# 인력유지율           -0.0057      0.014     -0.393      0.695      -0.034       0.023
# 여성평균급여대비총합      -0.0101      0.015     -0.681      0.496      -0.039       0.019
# 여성평균근속연수대비총합    -0.0143      0.015     -0.976      0.329      -0.043       0.014
# 가족친화인증          -0.0701      0.061     -1.141      0.254      -0.191       0.050
# 고용관련인증          -0.1593      1.457     -0.109      0.913      -3.015       2.696
# 지가경발간           -0.0605      0.186     -0.326      0.745      -0.424       0.303
# 지가경공시            1.4026      3.183      0.441      0.659      -4.837       7.642
# 공정위위반횟수          0.0089      0.012      0.765      0.444      -0.014       0.032
# ESG채권           -0.5600      5.890     -0.095      0.924     -12.104      10.984
# 소비자중심경영         -1.1183      5.735     -0.195      0.845     -12.360      10.123
# 지역사회공헌          -0.8628      5.814     -0.148      0.882     -12.258      10.532
# 정보보호공시          -0.0650      0.037     -1.742      0.081      -0.138       0.008
# 잡플래닛평점          -0.0587      0.015     -3.901      0.000      -0.088      -0.029
# 신규채용률           -0.0125      0.010     -1.251      0.211      -0.032       0.007
# 기부_투자           -1.0691      2.941     -0.364      0.716      -6.833       4.695
# S_risk          -0.0165      0.010     -1.621      0.105      -0.037       0.003
# ================================================================================
# ### print model summary ###
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                S_GRADE   No. Observations:                  661
# Model:                        MNLogit   Df Residuals:                      477
# Method:                           MLE   Df Model:                          176
# Date:                Sat, 15 Oct 2022   Pseudo R-squ.:                  0.2941
# Time:                        16:57:25   Log-Likelihood:                -905.51
# converged:                       True   LL-Null:                       -1282.8
# Covariance Type:            nonrobust   LLR p-value:                 1.251e-72
# ================================================================================
#    S_GRADE=2       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율           0.0623      0.142      0.439      0.661      -0.216       0.341
# ESG임원비율         -0.2892      0.135     -2.148      0.032      -0.553      -0.025
# 미등기여성임원비율21      0.1297      0.134      0.965      0.335      -0.134       0.393
# 여성직원비율           0.0459      0.831      0.055      0.956      -1.582       1.674
# 업종별여성비율         -1.5936      0.766     -2.081      0.037      -3.094      -0.093
# 정규직비율           -0.4866      0.353     -1.377      0.169      -1.179       0.206
# 인력유지율            0.1266      0.560      0.226      0.821      -0.971       1.224
# 여성평균급여대비총합      -0.7147      0.630     -1.134      0.257      -1.949       0.520
# 여성평균근속연수대비총합     0.6257      0.660      0.948      0.343      -0.667       1.919
# 가족친화인증           0.2192      0.999      0.219      0.826      -1.738       2.177
# 고용관련인증           6.8857     12.317      0.559      0.576     -17.255      31.026
# 지가경발간           -0.5781      1.644     -0.352      0.725      -3.801       2.644
# 지가경공시            0.4436      0.877      0.506      0.613      -1.276       2.163
# 공정위위반횟수          0.0843      0.156      0.541      0.588      -0.221       0.390
# ESG채권            1.2938      1.279      1.011      0.312      -1.213       3.801
# 소비자중심경영          0.5848      1.579      0.370      0.711      -2.511       3.680
# 지역사회공헌           0.2511      1.484      0.169      0.866      -2.658       3.160
# 정보보호공시          -0.6250      1.155     -0.541      0.588      -2.889       1.639
# 잡플래닛평점          -0.0597      0.737     -0.081      0.935      -1.504       1.385
# 신규채용률           -0.4919      0.398     -1.236      0.216      -1.272       0.288
# 기부_투자           -2.1131      1.592     -1.328      0.184      -5.233       1.007
# S_risk           0.2911      0.960      0.303      0.762      -1.590       2.172
# const            4.0374      2.375      1.700      0.089      -0.617       8.692
# --------------------------------------------------------------------------------
#    S_GRADE=3       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율           0.1080      0.145      0.748      0.455      -0.175       0.391
# ESG임원비율         -0.4115      0.140     -2.946      0.003      -0.685      -0.138
# 미등기여성임원비율21      0.0931      0.137      0.681      0.496      -0.175       0.361
# 여성직원비율          -0.5532      0.826     -0.670      0.503      -2.172       1.066
# 업종별여성비율         -0.8823      0.741     -1.191      0.234      -2.334       0.570
# 정규직비율           -0.0753      0.351     -0.215      0.830      -0.763       0.612
# 인력유지율            1.0962      0.570      1.922      0.055      -0.022       2.214
# 여성평균급여대비총합      -0.6231      0.610     -1.021      0.307      -1.820       0.573
# 여성평균근속연수대비총합     0.9738      0.662      1.471      0.141      -0.323       2.271
# 가족친화인증           0.0232      1.010      0.023      0.982      -1.956       2.002
# 고용관련인증          -3.6631    445.347     -0.008      0.993    -876.527     869.201
# 지가경발간           -1.8772      1.576     -1.191      0.234      -4.967       1.212
# 지가경공시           -1.0096      0.917     -1.101      0.271      -2.807       0.788
# 공정위위반횟수          0.1449      0.154      0.940      0.347      -0.157       0.447
# ESG채권            0.8985      1.411      0.637      0.524      -1.867       3.664
# 소비자중심경영          0.3093      1.648      0.188      0.851      -2.920       3.539
# 지역사회공헌           0.7882      1.497      0.527      0.599      -2.146       3.722
# 정보보호공시          -0.3785      1.175     -0.322      0.747      -2.682       1.925
# 잡플래닛평점          -0.4192      0.725     -0.578      0.563      -1.840       1.002
# 신규채용률           -0.0931      0.435     -0.214      0.831      -0.947       0.760
# 기부_투자           -0.7106      1.594     -0.446      0.656      -3.836       2.414
# S_risk          -0.7805      0.945     -0.826      0.409      -2.632       1.071
# const            5.7381      2.358      2.434      0.015       1.117      10.359
# --------------------------------------------------------------------------------
#    S_GRADE=4       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율           0.0959      0.146      0.658      0.511      -0.190       0.382
# ESG임원비율         -0.3398      0.141     -2.418      0.016      -0.615      -0.064
# 미등기여성임원비율21      0.0618      0.137      0.451      0.652      -0.206       0.330
# 여성직원비율          -0.0908      0.826     -0.110      0.912      -1.709       1.528
# 업종별여성비율         -1.1119      0.749     -1.486      0.137      -2.579       0.355
# 정규직비율            0.1462      0.345      0.424      0.671      -0.530       0.822
# 인력유지율            0.7254      0.567      1.280      0.201      -0.386       1.836
# 여성평균급여대비총합      -0.8427      0.610     -1.381      0.167      -2.039       0.353
# 여성평균근속연수대비총합     0.7917      0.663      1.194      0.232      -0.508       2.091
# 가족친화인증          -0.1359      1.019     -0.133      0.894      -2.133       1.861
# 고용관련인증           8.5659     12.815      0.668      0.504     -16.551      33.683
# 지가경발간           -2.5754      1.580     -1.630      0.103      -5.673       0.522
# 지가경공시           -0.4684      0.956     -0.490      0.624      -2.341       1.405
# 공정위위반횟수          0.1901      0.156      1.221      0.222      -0.115       0.495
# ESG채권            0.2746      1.486      0.185      0.853      -2.638       3.187
# 소비자중심경영         -1.0374      1.827     -0.568      0.570      -4.618       2.544
# 지역사회공헌           0.4703      1.552      0.303      0.762      -2.571       3.512
# 정보보호공시          -0.6088      1.172     -0.519      0.603      -2.906       1.688
# 잡플래닛평점          -0.8443      0.731     -1.155      0.248      -2.276       0.588
# 신규채용률           -0.3672      0.416     -0.883      0.377      -1.182       0.448
# 기부_투자           -0.9697      1.599     -0.607      0.544      -4.103       2.163
# S_risk          -0.2725      0.960     -0.284      0.777      -2.154       1.609
# const            6.7127      2.349      2.858      0.004       2.109      11.316
# --------------------------------------------------------------------------------
#    S_GRADE=5       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율          -0.0181      0.152     -0.119      0.905      -0.316       0.279
# ESG임원비율         -0.3870      0.155     -2.504      0.012      -0.690      -0.084
# 미등기여성임원비율21      0.1096      0.143      0.767      0.443      -0.170       0.390
# 여성직원비율          -0.7517      0.859     -0.875      0.381      -2.435       0.931
# 업종별여성비율         -0.7671      0.777     -0.988      0.323      -2.290       0.755
# 정규직비율            0.0580      0.354      0.164      0.870      -0.636       0.752
# 인력유지율            0.6199      0.579      1.071      0.284      -0.514       1.754
# 여성평균급여대비총합      -0.0910      0.625     -0.146      0.884      -1.316       1.134
# 여성평균근속연수대비총합     0.6917      0.668      1.035      0.301      -0.618       2.001
# 가족친화인증          -0.4386      1.036     -0.423      0.672      -2.470       1.593
# 고용관련인증           8.5271     12.827      0.665      0.506     -16.613      33.667
# 지가경발간           -3.3864      1.633     -2.073      0.038      -6.587      -0.185
# 지가경공시           -1.6218      1.204     -1.347      0.178      -3.981       0.738
# 공정위위반횟수          0.3252      0.163      1.990      0.047       0.005       0.645
# ESG채권           -8.2393     38.619     -0.213      0.831     -83.931      67.452
# 소비자중심경영          1.2805      1.683      0.761      0.447      -2.019       4.580
# 지역사회공헌          -8.2771     38.431     -0.215      0.829     -83.601      67.047
# 정보보호공시          -0.7386      1.203     -0.614      0.539      -3.096       1.619
# 잡플래닛평점          -0.6845      0.737     -0.929      0.353      -2.128       0.759
# 신규채용률           -0.5074      0.414     -1.225      0.221      -1.320       0.305
# 기부_투자           -1.3735      1.627     -0.844      0.399      -4.563       1.816
# S_risk          -0.3712      0.958     -0.388      0.698      -2.248       1.506
# const            7.9835      2.387      3.344      0.001       3.304      12.663
# --------------------------------------------------------------------------------
#    S_GRADE=6       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율          -0.0130      0.156     -0.084      0.933      -0.318       0.292
# ESG임원비율         -0.4546      0.170     -2.670      0.008      -0.788      -0.121
# 미등기여성임원비율21     -0.0065      0.147     -0.044      0.965      -0.295       0.282
# 여성직원비율          -0.9670      0.858     -1.128      0.259      -2.648       0.714
# 업종별여성비율         -0.5632      0.777     -0.725      0.469      -2.086       0.960
# 정규직비율            0.0777      0.352      0.221      0.825      -0.613       0.768
# 인력유지율            0.7973      0.579      1.377      0.168      -0.337       1.932
# 여성평균급여대비총합      -0.5918      0.623     -0.950      0.342      -1.813       0.630
# 여성평균근속연수대비총합     0.8333      0.670      1.243      0.214      -0.481       2.147
# 가족친화인증          -0.4887      1.055     -0.463      0.643      -2.556       1.578
# 고용관련인증           9.3098     12.818      0.726      0.468     -15.813      34.433
# 지가경발간           -3.1424      1.668     -1.884      0.060      -6.412       0.127
# 지가경공시           -1.1992      1.481     -0.810      0.418      -4.101       1.703
# 공정위위반횟수          0.1365      0.183      0.745      0.456      -0.222       0.495
# ESG채권            1.2223      1.838      0.665      0.506      -2.380       4.825
# 소비자중심경영         -7.9705     39.215     -0.203      0.839     -84.831      68.890
# 지역사회공헌           0.3642      1.677      0.217      0.828      -2.922       3.651
# 정보보호공시          -1.5478      1.205     -1.285      0.199      -3.909       0.814
# 잡플래닛평점          -0.8497      0.739     -1.150      0.250      -2.298       0.598
# 신규채용률           -0.1936      0.439     -0.440      0.660      -1.055       0.668
# 기부_투자           -2.9082      1.684     -1.727      0.084      -6.208       0.391
# S_risk          -0.2163      0.958     -0.226      0.821      -2.095       1.662
# const            7.0912      2.462      2.880      0.004       2.266      11.916
# --------------------------------------------------------------------------------
#    S_GRADE=7       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율           0.0653      0.150      0.434      0.664      -0.230       0.360
# ESG임원비율         -0.5604      0.182     -3.075      0.002      -0.918      -0.203
# 미등기여성임원비율21      0.0863      0.142      0.606      0.545      -0.193       0.365
# 여성직원비율          -0.9602      0.847     -1.134      0.257      -2.620       0.700
# 업종별여성비율         -0.3792      0.765     -0.496      0.620      -1.878       1.120
# 정규직비율            0.1574      0.348      0.452      0.651      -0.525       0.839
# 인력유지율            0.7322      0.572      1.281      0.200      -0.389       1.853
# 여성평균급여대비총합      -0.3101      0.616     -0.504      0.615      -1.517       0.897
# 여성평균근속연수대비총합     0.9531      0.665      1.433      0.152      -0.351       2.257
# 가족친화인증          -1.9760      1.075     -1.839      0.066      -4.082       0.130
# 고용관련인증           8.3249     12.823      0.649      0.516     -16.808      33.458
# 지가경발간           -5.0933      1.885     -2.703      0.007      -8.787      -1.400
# 지가경공시           -6.9173     35.307     -0.196      0.845     -76.118      62.283
# 공정위위반횟수          0.1483      0.182      0.814      0.416      -0.209       0.505
# ESG채권           -5.4544     40.061     -0.136      0.892     -83.973      73.065
# 소비자중심경영         -1.6814      1.999     -0.841      0.400      -5.599       2.236
# 지역사회공헌          -9.0464     38.201     -0.237      0.813     -83.920      65.827
# 정보보호공시          -1.4058      1.189     -1.182      0.237      -3.737       0.925
# 잡플래닛평점          -0.8936      0.731     -1.223      0.221      -2.326       0.539
# 신규채용률           -0.4408      0.421     -1.048      0.295      -1.265       0.384
# 기부_투자           -2.6457      1.682     -1.573      0.116      -5.942       0.650
# S_risk          -0.4251      0.951     -0.447      0.655      -2.290       1.440
# const            8.3137      2.455      3.386      0.001       3.502      13.125
# --------------------------------------------------------------------------------
#    S_GRADE=8       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율           0.0739      0.149      0.497      0.620      -0.218       0.366
# ESG임원비율         -0.5922      0.190     -3.124      0.002      -0.964      -0.221
# 미등기여성임원비율21      0.0605      0.141      0.428      0.669      -0.216       0.337
# 여성직원비율          -0.9078      0.843     -1.078      0.281      -2.559       0.743
# 업종별여성비율         -0.6912      0.762     -0.907      0.364      -2.185       0.803
# 정규직비율            0.1872      0.347      0.540      0.589      -0.492       0.867
# 인력유지율            0.8452      0.568      1.488      0.137      -0.268       1.959
# 여성평균급여대비총합      -0.3621      0.614     -0.590      0.555      -1.565       0.840
# 여성평균근속연수대비총합     0.7190      0.661      1.088      0.277      -0.577       2.015
# 가족친화인증          -1.8304      1.054     -1.736      0.083      -3.897       0.236
# 고용관련인증           7.4113     12.831      0.578      0.564     -17.736      32.559
# 지가경발간           -5.5408      1.903     -2.912      0.004      -9.271      -1.811
# 지가경공시            1.3253      1.811      0.732      0.464      -2.224       4.875
# 공정위위반횟수          0.1107      0.177      0.626      0.531      -0.236       0.457
# ESG채권           -4.7508     39.110     -0.121      0.903     -81.405      71.904
# 소비자중심경영         -0.9715      1.864     -0.521      0.602      -4.624       2.681
# 지역사회공헌          -1.2226      1.817     -0.673      0.501      -4.784       2.339
# 정보보호공시          -1.9189      1.185     -1.620      0.105      -4.240       0.403
# 잡플래닛평점          -1.5119      0.730     -2.072      0.038      -2.942      -0.082
# 신규채용률           -0.5102      0.418     -1.220      0.223      -1.330       0.310
# 기부_투자           -2.8378      1.697     -1.672      0.095      -6.164       0.489
# S_risk          -0.5383      0.950     -0.567      0.571      -2.400       1.323
# const            8.5179      2.462      3.459      0.001       3.692      13.344
# --------------------------------------------------------------------------------
#    S_GRADE=9       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# 여성임원비율           0.0618      0.151      0.410      0.682      -0.233       0.357
# ESG임원비율         -2.4478     15.309     -0.160      0.873     -32.453      27.558
# 미등기여성임원비율21      0.0074      0.144      0.051      0.959      -0.275       0.290
# 여성직원비율          -1.1041      0.850     -1.300      0.194      -2.769       0.561
# 업종별여성비율         -0.7434      0.767     -0.969      0.333      -2.247       0.761
# 정규직비율            0.1098      0.347      0.316      0.752      -0.571       0.791
# 인력유지율            0.7607      0.569      1.336      0.181      -0.355       1.876
# 여성평균급여대비총합      -0.4391      0.615     -0.714      0.475      -1.645       0.767
# 여성평균근속연수대비총합     0.6896      0.662      1.041      0.298      -0.608       1.987
# 가족친화인증          -2.0488      1.079     -1.899      0.058      -4.163       0.066
# 고용관련인증           6.5403     12.860      0.509      0.611     -18.664      31.745
# 지가경발간           -5.3359      1.951     -2.735      0.006      -9.160      -1.512
# 지가경공시            8.4157     19.908      0.423      0.672     -30.603      47.434
# 공정위위반횟수          0.1972      0.174      1.130      0.258      -0.145       0.539
# ESG채권           -8.1579     31.352     -0.260      0.795     -69.607      53.292
# 소비자중심경영         -9.0431     38.624     -0.234      0.815     -84.746      66.659
# 지역사회공헌          -9.0646     38.203     -0.237      0.812     -83.941      65.812
# 정보보호공시          -2.0610      1.191     -1.731      0.083      -4.394       0.272
# 잡플래닛평점          -1.6119      0.731     -2.204      0.028      -3.045      -0.178
# 신규채용률           -0.5405      0.419     -1.291      0.197      -1.361       0.280
# 기부_투자           -9.8217     19.907     -0.493      0.622     -48.838      29.195
# S_risk          -0.5817      0.950     -0.612      0.540      -2.444       1.280
# const           -1.0054     79.628     -0.013      0.990    -157.074     155.063
# ================================================================================

# %% [markdown]
# - 선택한 모형의 결과 값이다. 결과에 대한 해석은 다음과 같으며 그 이유에 대해서는 G_FinalModeling에 자세하게 있으므로 생략한다.
#
# - marginal summary의 경우는 다음과 같이 해석한다. 결과적으로 회귀계수가 + 값을 가지면 그 설명변수가 커질수록 해당 카테고리가 될 확률 이 커지는 방향으로 움직인다. 회귀계수가 - 값을 가지면 그 설명변수가 작아질수록 해당 카테고리가 될 확률이 커지는 방향으로 움직인다.
#
#
# - 전체 model summary의 경우는 다음과 같이 해석한다. 결과적으로 회귀계수가 + 값을 가지면 그 설명변수가 커질수록 G1에 비해 다른 카테고리가 될 확률이 커진다는 의미이고, 회귀계수가 - 값을 가지면 그 설명변수가 커질수록 G1에 비해 다른 카테고리가 될 확률이 작아지게 된다는 의미이다.
#
# - LLR p-value도 유의하게 나온 것으로 보아 모델은 어느 정도 성능을 보장하지만 R-squ 값이 작아 설명력이 떨어지고 상관계수가 큰 변수들이 존재했기 때문에 변수 선택을 진행한다.

# %% [markdown]
# #### Result에 따른 variable selection
# - AIC는 작을수록 좋기 때문에 전체 변수에서 제거했을 때 AIC가 가장 작아지는 변수를 제거하는 후진제거법으로 변수선택을 진행하였다.

# %%
# 초기값 입력
# x : 모델링 시 r_train의 covariate 값에 constant 부분을 더해준 train set
data = copy.deepcopy(x)
predictor=x.columns.difference(['const']) #x의 변수명

can_model = [] #후보가 될 model들이 들어갈 어레이 할당
candidate = [] #후보가 될 result들이 들어갈 어레이 할당
can_var = [] #제거되는 변수명이 들어갈 어레이 할당

model = sm.MNLogit(y_train, data)
regr = model.fit(method='lbfgs', maxiter=100000) #full model에 대해 모델 적합
can_model.append(model)
candidate.append(regr)
can_var.append('Full')

# 변수 선택 시작
for i in range(len(x.columns)-1) :
# for문 시작
    r_model=[]
    result=[]
    dropped=[]
    AIC = []
    
    #아무것도 제거하지 않은 full data에 대해 적합
    model = sm.MNLogit(y_train, data)
    regr = model.fit(method='lbfgs', maxiter=100000)
    r_model.append(model)
    result.append(regr)
    dropped.append('no')
    AIC.append(regr.aic)
    
    # 변수를 하나씩 제거하면서 data 적합하여 모델을 result에 저장
    # 제거한 변수는 dropped에 저장
    # 변수를 제거했을 때 나온 AIC는 AIC에 저장
    for var in predictor :
        model = sm.MNLogit(y_train, data.drop(var, inplace=False, axis=1))
        regr = model.fit(method='lbfgs', maxiter=100000)
        r_model.append(model)
        result.append(regr)
        dropped.append(var)
        AIC.append(regr.aic)

    # AIC가 가장 작은 best 모형을 찾기 위해 데이터프레임을 만들고 AIC 기준으로 sorting
    best = pd.DataFrame({'model':r_model,'model_result':result, 'AIC':AIC, 'dropped':dropped})
    best = best.sort_values(by='AIC', ascending=True, ignore_index=True)
    best.head(3) 
    can_model.append(best.loc[0,'model']) #가장 좋은 모델을 can_model에 저장
    candidate.append(best.loc[0,'model_result']) #가장 좋은 모델은 candidate에 저장
    can_var.append(best.loc[0,'dropped']) #가장 좋은 모델을 만들기 위해 버린 변수명을 can_var에 저장
    if best.loc[0,'dropped']=='no' :  # 만약 가장 좋은 모델로 Full model이 뽑힌다면 for문을 종료
        break
    data.drop(columns=best.loc[0,'dropped'], inplace=True)
    predictor=data.columns.difference(['const'])

# 비어있는 array할당해서 해당 모델의 AIC 값 저장  
AIC=[]
for i in range(len(candidate)) :
    AIC.append(candidate[i].aic)

# 비어있는 array 할당  
acc_vec=[]
nearest_acc_vec=[]
under_est_vec=[]
over3_est_vec=[]

# 본 팀에서 만든 3가지 지표를 활용하기 위해 AIC 기준으로 뽑힌 모델들을 이용해 y값을 예측
data = copy.deepcopy(x)
real = r_train['S_GRADE']
for i in range(len(candidate)) :# candidate으로 저장한 dataframe에서 drop된 변수, model, model 적합값 가져옴
    d_var = can_var[i]
    model = can_model[i]
    result = candidate[i]
    if d_var=='Full' :# full model인 경우 변수 제거 없이 추정 진행
        x=sm.add_constant(x_train, prepend=False)
        pred=model.predict(result.params,x)
        pred = pred.argmax(1) + 1
        pred = pd.Series(pred)
        m = make_confusionmatrix(real, pred)
        acc_vec.append(acc(m))
        nearest_acc_vec.append(nearest_acc(m))
        under_est_vec.append(under_est(m))
        over3_est_vec.append(over3_est(m))
    elif d_var=='no':
        pred=model.predict(result.params,data)
        pred = pred.argmax(1) + 1
        pred = pd.Series(pred)
        m = make_confusionmatrix(real, pred)
        acc_vec.append(acc(m))
        nearest_acc_vec.append(nearest_acc(m))
        under_est_vec.append(under_est(m))
        over3_est_vec.append(over3_est(m))
    else : #그 외의 경우 해당 변수 제거 후 추정 진행
        data.drop(columns=d_var, inplace=True)
        pred=model.predict(result.params,data)
        pred = pred.argmax(1) + 1
        pred = pd.Series(pred)
        m = make_confusionmatrix(real, pred)
        acc_vec.append(acc(m))
        nearest_acc_vec.append(nearest_acc(m))
        under_est_vec.append(under_est(m))
        over3_est_vec.append(over3_est(m))
    
candidate_model = pd.DataFrame({'candidate_model':can_model,'result':candidate,'dropped':can_var, 'AIC':AIC, '정확도':acc_vec, 
                                '근접정확도':nearest_acc_vec, '과소추정오류비':under_est_vec, '3단계과추정률':over3_est_vec})
# 후진 제거법으로 선택한 모형
candidate_model.drop(columns=['candidate_model','result'], inplace=False)
# Out:
#          dropped          AIC       정확도     근접정확도   과소추정오류비   3단계과추정률
# 0           Full  2179.018515  0.443268  0.779123  0.586957  0.192935
# 1         여성임원비율  2167.438449  0.440242  0.779123  0.578378  0.183784
# 2    미등기여성임원비율21  2156.535168  0.444781  0.783661  0.588556  0.193460
# 3   여성평균근속연수대비총합  2146.834500  0.440242  0.777610  0.578378  0.194595
# 4          ESG채권  2137.855005  0.443268  0.777610  0.581522  0.187500
# 5        공정위위반횟수  2129.099422  0.447806  0.788200  0.594521  0.197260
# 6         여성직원비율  2123.426875  0.438729  0.786687  0.598383  0.183288
# 7          정규직비율  2118.269818  0.432678  0.786687  0.584000  0.184000
# 8         고용관련인증  2113.794264  0.425113  0.776097  0.578947  0.194737
# 9          인력유지율  2110.736896  0.422088  0.767020  0.573298  0.185864
# 10    여성평균급여대비총합  2108.482582  0.408472  0.763994  0.588235  0.191816
# 11         신규채용률  2107.137467  0.409985  0.768533  0.600000  0.197436
# 12         지가경공시  2105.679324  0.397882  0.767020  0.610553  0.193467
# 13        지역사회공헌  2105.522334  0.396369  0.767020  0.598997  0.195489
# 14            no  2105.522334  0.396369  0.767020  0.598997  0.195489

# %% [markdown]
# - 후진 제거법으로 선택된 모형들에 대한 정보는 위와 같다.
# - 최종 제거된 변수는 여성임원비율, 미등기여성임원비율21, 여성평균근속연수대비총합, ESG채권, 공정위위반횟수, 여성직원비율, 정규직비율, 고용관련인증, 인력유지율, 여성평균급여대비총합, 신규채용률, 지가경공시, 지역사회공헌이다.

# %%
## 선택한 모형들의 AIC, dropped variable, summary 출력
for i in range(candidate_model.shape[0]) :
    print('### ', i, 'th selected model ###')
    print("AIC: ", candidate_model.loc[i,'AIC'], "dropped value: ", candidate_model.loc[i,'dropped'])
    print(check_beta(candidate_model.loc[i,'result']))
# Out:
# ###  0 th selected model ###
# AIC:  2179.018515414632 dropped value:  Full
# 0        여성임원비율     ESG임원비율 미등기여성임원비율21      여성직원비율     업종별여성비율       정규직비율  \
# S=2      0.0623     -0.2892      0.1297      0.0459     -1.5936     -0.4866
# S=3      0.1080     -0.4115      0.0931     -0.5532     -0.8823     -0.0753
# S=4      0.0959     -0.3398      0.0618     -0.0908     -1.1119      0.1462
# S=5     -0.0181     -0.3870      0.1096     -0.7517     -0.7671      0.0580
# S=6     -0.0130     -0.4546     -0.0065     -0.9670     -0.5632      0.0777
# S=7      0.0653     -0.5604      0.0863     -0.9602     -0.3792      0.1574
# S=8      0.0739     -0.5922      0.0605     -0.9078     -0.6912      0.1872
# S=9      0.0618     -2.4478      0.0074     -1.1041     -0.7434      0.1098
#
# 0         인력유지율  여성평균급여대비총합 여성평균근속연수대비총합      가족친화인증  ...     공정위위반횟수  \
# S=2      0.1266     -0.7147       0.6257      0.2192  ...      0.0843
# S=3      1.0962     -0.6231       0.9738      0.0232  ...      0.1449
# S=4      0.7254     -0.8427       0.7917     -0.1359  ...      0.1901
# S=5      0.6199     -0.0910       0.6917     -0.4386  ...      0.3252
# S=6      0.7973     -0.5918       0.8333     -0.4887  ...      0.1365
# S=7      0.7322     -0.3101       0.9531     -1.9760  ...      0.1483
# S=8      0.8452     -0.3621       0.7190     -1.8304  ...      0.1107
# S=9      0.7607     -0.4391       0.6896     -2.0488  ...      0.1972
#
# 0         ESG채권     소비자중심경영      지역사회공헌      정보보호공시      잡플래닛평점       신규채용률  \
# S=2      1.2938      0.5848      0.2511     -0.6250     -0.0597     -0.4919
# S=3      0.8985      0.3093      0.7882     -0.3785     -0.4192     -0.0931
# S=4      0.2746     -1.0374      0.4703     -0.6088     -0.8443     -0.3672
# S=5     -8.2393      1.2805     -8.2771     -0.7386     -0.6845     -0.5074
# S=6      1.2223     -7.9705      0.3642     -1.5478     -0.8497     -0.1936
# S=7     -5.4544     -1.6814     -9.0464     -1.4058     -0.8936     -0.4408
# S=8     -4.7508     -0.9715     -1.2226     -1.9189     -1.5119     -0.5102
# S=9     -8.1579     -9.0431     -9.0646     -2.0610     -1.6119     -0.5405
#
# 0         기부_투자      S_risk       const
# S=2     -2.1131      0.2911      4.0374
# S=3     -0.7106     -0.7805      5.7381
# S=4     -0.9697     -0.2725      6.7127
# S=5     -1.3735     -0.3712      7.9835
# S=6     -2.9082     -0.2163      7.0912
# S=7     -2.6457     -0.4251      8.3137
# S=8     -2.8378     -0.5383      8.5179
# S=9     -9.8217     -0.5817     -1.0054
#
# [8 rows x 23 columns]
# ###  1 th selected model ###
# AIC:  2167.4384490568473 dropped value:  여성임원비율
# 0       ESG임원비율 미등기여성임원비율21      여성직원비율     업종별여성비율       정규직비율       인력유지율  \
# S=2     -0.2807      0.1254      0.0780     -1.6092     -0.4784      0.1751
# S=3     -0.4029      0.0863     -0.5200     -0.8740     -0.0664      1.1469
# S=4     -0.3283      0.0540     -0.0509     -1.1157      0.1536      0.7761
# S=5     -0.3898      0.1002     -0.7636     -0.7733      0.0710      0.6791
# S=6     -0.4463     -0.0098     -0.9709     -0.5806      0.0897      0.8545
# S=7     -0.5444      0.0804     -0.9393     -0.3772      0.1694      0.7873
# S=8     -0.5739      0.0538     -0.8771     -0.6922      0.2000      0.8990
# S=9     -2.4262      0.0008     -1.0824     -0.7434      0.1224      0.8160
#
# 0    여성평균급여대비총합 여성평균근속연수대비총합      가족친화인증      고용관련인증  ...     공정위위반횟수  \
# S=2     -0.7509       0.5874      0.0857      7.2371  ...      0.0956
# S=3     -0.6518       0.9068     -0.0776     -3.8237  ...      0.1607
# S=4     -0.8694       0.7358     -0.2619      8.8626  ...      0.2048
# S=5     -0.1466       0.6579     -0.5183      8.9307  ...      0.3290
# S=6     -0.6508       0.8030     -0.6491      9.7307  ...      0.1501
# S=7     -0.3488       0.9066     -2.0858      8.7325  ...      0.1562
# S=8     -0.3993       0.6704     -1.9365      7.8239  ...      0.1180
# S=9     -0.4797       0.6432     -2.1640      6.9412  ...      0.2036
#
# 0         ESG채권     소비자중심경영      지역사회공헌      정보보호공시      잡플래닛평점       신규채용률  \
# S=2      1.4648      0.7574      0.3263     -0.5733      0.0068     -0.4947
# S=3      1.1174      0.5154      0.8962     -0.4141     -0.3242     -0.0736
# S=4      0.4906     -0.8229      0.5953     -0.6137     -0.7588     -0.3665
# S=5     -7.7518      1.3486     -8.3178     -0.6669     -0.6199     -0.5037
# S=6      1.3255     -7.7748      0.2774     -1.4481     -0.7906     -0.2008
# S=7     -5.1608     -1.4657     -8.9221     -1.3593     -0.8255     -0.4353
# S=8     -4.4764     -0.7374     -1.1324     -1.8678     -1.4468     -0.5048
# S=9     -7.8325     -8.7310     -8.9366     -2.0076     -1.5452     -0.5356
#
# 0         기부_투자      S_risk       const
# S=2     -2.1439      0.3014      3.8351
# S=3     -0.7967     -0.7530      5.4346
# S=4     -1.0254     -0.2425      6.4440
# S=5     -1.4094     -0.3640      7.9745
# S=6     -2.9101     -0.2135      7.1867
# S=7     -2.6965     -0.4141      8.1163
# S=8     -2.8763     -0.5272      8.2917
# S=9     -9.8709     -0.5713     -1.1736
#
# [8 rows x 22 columns]
# ###  2 th selected model ###
# AIC:  2156.5351675364627 dropped value:  미등기여성임원비율21
# 0       ESG임원비율      여성직원비율     업종별여성비율       정규직비율       인력유지율  여성평균급여대비총합  \
# S=2     -0.2838      0.3414     -1.7550     -0.4634      0.1803     -0.7439
# S=3     -0.4070     -0.2740     -1.0261     -0.0657      1.1712     -0.6553
# S=4     -0.3329      0.1480     -1.2578      0.1545      0.8041     -0.8847
# S=5     -0.3936     -0.4785     -0.9528      0.0683      0.7148     -0.1409
# S=6     -0.4556     -0.8434     -0.7181      0.0925      0.8834     -0.6724
# S=7     -0.5498     -0.6904     -0.5454      0.1693      0.8201     -0.3559
# S=8     -0.5795     -0.6824     -0.8365      0.2025      0.9276     -0.4170
# S=9     -2.3875     -0.9242     -0.8724      0.1268      0.8446     -0.5120
#
# 0   여성평균근속연수대비총합      가족친화인증      고용관련인증       지가경발간  ...     공정위위반횟수  \
# S=2       0.5255     -0.0119      8.4258     -0.1415  ...      0.0892
# S=3       0.8428     -0.1754     -4.0561     -1.4216  ...      0.1509
# S=4       0.6686     -0.3525      9.9145     -2.1638  ...      0.1956
# S=5       0.5857     -0.6216     10.0214     -3.1334  ...      0.3182
# S=6       0.7297     -0.7271     10.7644     -2.9463  ...      0.1343
# S=7       0.8320     -2.1790      9.7981     -4.6366  ...      0.1469
# S=8       0.5973     -2.0242      8.8879     -5.1358  ...      0.1083
# S=9       0.5769     -2.2418      8.0204     -5.0005  ...      0.1928
#
# 0         ESG채권     소비자중심경영      지역사회공헌      정보보호공시      잡플래닛평점       신규채용률  \
# S=2      1.4724      0.4524      0.5109     -0.5613      0.0353     -0.4630
# S=3      1.1222      0.2460      1.0280     -0.3769     -0.2972     -0.0585
# S=4      0.4944     -1.0328      0.7195     -0.5916     -0.7313     -0.3606
# S=5     -7.8830      1.0793     -8.4480     -0.6146     -0.5849     -0.4890
# S=6      1.4207     -8.3545      0.4340     -1.4765     -0.7767     -0.2043
# S=7     -5.4178     -1.7371     -8.9882     -1.3207     -0.7899     -0.4249
# S=8     -4.8228     -1.0157     -0.9607     -1.8560     -1.4224     -0.4945
# S=9     -9.0078     -9.4059     -9.0226     -2.0103     -1.5257     -0.5269
#
# 0         기부_투자      S_risk       const
# S=2     -2.1563      0.1790      3.3812
# S=3     -0.8037     -0.8332      5.0429
# S=4     -1.0462     -0.3211      6.1688
# S=5     -1.4002     -0.4461      7.5158
# S=6     -2.9367     -0.3027      7.1227
# S=7     -2.6858     -0.4998      7.7261
# S=8     -2.8898     -0.6087      8.0100
# S=9    -10.1025     -0.6540     -1.0116
#
# [8 rows x 21 columns]
# ###  3 th selected model ###
# AIC:  2146.8344997332615 dropped value:  여성평균근속연수대비총합
# 0       ESG임원비율      여성직원비율     업종별여성비율       정규직비율       인력유지율  여성평균급여대비총합  \
# S=2     -0.2654      0.4599     -1.6338     -0.4438      0.2264     -0.5729
# S=3     -0.3857     -0.0597     -0.9332     -0.0628      1.2455     -0.4407
# S=4     -0.3138      0.3150     -1.1574      0.1582      0.8609     -0.7029
# S=5     -0.3755     -0.3206     -0.8685      0.0719      0.7624      0.0195
# S=6     -0.4372     -0.6662     -0.6110      0.0927      0.9393     -0.4796
# S=7     -0.5247     -0.5039     -0.4450      0.1704      0.8849     -0.1475
# S=8     -0.5675     -0.5285     -0.7355      0.2012      0.9806     -0.2527
# S=9     -2.3071     -0.7799     -0.7726      0.1251      0.8950     -0.3572
#
# 0        가족친화인증      고용관련인증       지가경발간       지가경공시     공정위위반횟수       ESG채권  \
# S=2      0.1099      9.3829     -0.0054      0.4154      0.0808      1.5748
# S=3     -0.0734     -3.8685     -1.2351     -1.0809      0.1383      1.2175
# S=4     -0.2309     10.9176     -2.0272     -0.5178      0.1839      0.6057
# S=5     -0.4831     11.0431     -2.9733     -1.5400      0.3083     -8.0701
# S=6     -0.6195     11.7695     -2.8134     -1.2199      0.1202      1.5230
# S=7     -2.0562     10.7864     -4.5297     -7.5091      0.1345     -5.5795
# S=8     -1.9029      9.9012     -4.9361      1.2333      0.0960     -4.9617
# S=9     -2.1264      9.0200     -4.7547      8.9861      0.1830     -9.5450
#
# 0       소비자중심경영      지역사회공헌      정보보호공시      잡플래닛평점       신규채용률       기부_투자  \
# S=2      0.8718      0.3606     -0.5711      0.0363     -0.5481     -1.7242
# S=3      0.7470      0.8191     -0.5145     -0.2169     -0.1600     -0.3984
# S=4     -0.5535      0.5659     -0.6572     -0.6781     -0.4472     -0.6329
# S=5      1.5481     -8.9469     -0.6500     -0.5384     -0.5724     -0.9979
# S=6     -8.1143      0.2584     -1.5620     -0.7198     -0.2917     -2.5341
# S=7     -1.1615     -9.4945     -1.4244     -0.7420     -0.5216     -2.2750
# S=8     -0.5721     -1.1255     -1.8978     -1.3728     -0.5789     -2.5075
# S=9     -9.2915     -9.5119     -2.0518     -1.4761     -0.6107    -10.1029
#
# 0        S_risk       const
# S=2      0.0582      2.9611
# S=3     -0.9341      4.6136
# S=4     -0.4246      5.6962
# S=5     -0.5535      7.0344
# S=6     -0.3973      6.6546
# S=7     -0.5917      7.3202
# S=8     -0.7124      7.4960
# S=9     -0.7577     -1.1553
# ###  4 th selected model ###
# AIC:  2137.8550050476365 dropped value:  ESG채권
# 0       ESG임원비율      여성직원비율     업종별여성비율       정규직비율       인력유지율  여성평균급여대비총합  \
# S=2     -0.2391      0.4179     -1.5573     -0.3781      0.2201     -0.5155
# S=3     -0.3634     -0.1277     -0.8581     -0.0112      1.2433     -0.3844
# S=4     -0.3002      0.2426     -1.0832      0.1917      0.8478     -0.6513
# S=5     -0.3876     -0.3498     -0.8181      0.1215      0.7575      0.0289
# S=6     -0.4009     -0.7320     -0.5374      0.1380      0.9254     -0.4266
# S=7     -0.5195     -0.5577     -0.3764      0.2155      0.8770     -0.1099
# S=8     -0.5588     -0.5828     -0.6674      0.2466      0.9723     -0.2136
# S=9     -2.2437     -0.8348     -0.7043      0.1713      0.8866     -0.3172
#
# 0        가족친화인증      고용관련인증       지가경발간       지가경공시     공정위위반횟수     소비자중심경영  \
# S=2      0.2099      7.5938      0.0051      0.5240      0.0478      0.7197
# S=3      0.0637     -3.9431     -1.2302     -1.0100      0.1188      0.6683
# S=4     -0.1012      9.4975     -2.0603     -0.5194      0.1668     -0.6084
# S=5     -0.2936      9.6285     -2.7761     -1.6145      0.2613      1.4771
# S=6     -0.4721     10.3258     -2.7753     -1.1601      0.1053     -8.1487
# S=7     -1.8981      9.3508     -4.4473     -7.4392      0.1003     -1.2259
# S=8     -1.7471      8.4644     -4.8666      1.1358      0.0637     -0.6320
# S=9     -1.9687      7.5818     -4.6969      3.8626      0.1546     -9.1977
#
# 0        지역사회공헌      정보보호공시      잡플래닛평점       신규채용률       기부_투자      S_risk  \
# S=2      0.3141     -1.1660      0.1656     -0.5655     -1.9571      0.3401
# S=3      0.8019     -0.9464     -0.1274     -0.1666     -0.5387     -0.7851
# S=4      0.5408     -1.0716     -0.6225     -0.4605     -0.7427     -0.2602
# S=5     -9.0728     -1.0603     -0.4474     -0.5963     -1.1423     -0.4574
# S=6      0.2777     -1.9786     -0.6376     -0.2921     -2.6382     -0.2507
# S=7     -9.5425     -1.8369     -0.6607     -0.5376     -2.3829     -0.4664
# S=8     -1.1158     -2.3080     -1.2946     -0.5942     -2.5952     -0.5867
# S=9     -9.5551     -2.4557     -1.4015     -0.6268     -5.2714     -0.6329
#
# 0         const
# S=2      3.1572
# S=3      4.7875
# S=4      5.8300
# S=5      6.8385
# S=6      6.8971
# S=7      7.2918
# S=8      7.4942
# S=9     -0.8610
# ###  5 th selected model ###
# AIC:  2129.0994224638553 dropped value:  공정위위반횟수
# 0       ESG임원비율      여성직원비율     업종별여성비율       정규직비율       인력유지율  여성평균급여대비총합  \
# S=2     -0.2386      0.3825     -1.5346     -0.3633      0.2862     -0.4717
# S=3     -0.3607     -0.1954     -0.8602     -0.0299      1.2690     -0.2946
# S=4     -0.2912      0.1584     -1.0819      0.1655      0.8742     -0.5596
# S=5     -0.3685     -0.4814     -0.7907      0.1009      0.7750      0.1303
# S=6     -0.3992     -0.8023     -0.5394      0.1083      0.9479     -0.3232
# S=7     -0.5194     -0.6315     -0.3765      0.1846      0.9011     -0.0033
# S=8     -0.5606     -0.6556     -0.6711      0.2167      0.9963     -0.1070
# S=9     -2.1094     -0.9205     -0.6932      0.1397      0.9056     -0.2133
#
# 0        가족친화인증      고용관련인증       지가경발간       지가경공시     소비자중심경영      지역사회공헌  \
# S=2      0.1509      6.2382     -0.0367      0.5028      0.5972      0.3327
# S=3      0.0485     -4.1355     -1.2252     -1.0634      0.5291      0.8543
# S=4     -0.0832      7.8588     -1.9857     -0.5768     -0.7766      0.6303
# S=5     -0.2469      7.9029     -2.5890     -1.5015      1.2681     -9.4639
# S=6     -0.4954      8.7102     -2.7685     -1.2187     -8.6692      0.3471
# S=7     -1.9289      7.7272     -4.4242     -6.8236     -1.3684     -9.8708
# S=8     -1.8092      6.8480     -4.8895      0.9841     -0.7668     -1.0313
# S=9     -1.9897      5.9533     -4.6437      3.8454     -9.4603     -9.9161
#
# 0        정보보호공시      잡플래닛평점       신규채용률       기부_투자      S_risk       const
# S=2     -1.2105      0.0982     -0.6074     -1.8857      0.3826      3.0984
# S=3     -0.9123     -0.1858     -0.2261     -0.3701     -0.7204      4.2736
# S=4     -1.0274     -0.6816     -0.5125     -0.5711     -0.2041      5.0877
# S=5     -1.0423     -0.5112     -0.6597     -0.9431     -0.3924      5.7256
# S=6     -1.9449     -0.6871     -0.3454     -2.4859     -0.1868      6.4405
# S=7     -1.8113     -0.7143     -0.5923     -2.2255     -0.4010      6.8581
# S=8     -2.2839     -1.3497     -0.6487     -2.4489     -0.5205      7.2364
# S=9     -2.4250     -1.4536     -0.6797     -5.1163     -0.5655     -0.8634
# ###  6 th selected model ###
# AIC:  2123.4268746328125 dropped value:  여성직원비율
# 0       ESG임원비율     업종별여성비율       정규직비율       인력유지율  여성평균급여대비총합      가족친화인증  \
# S=2     -0.2237     -1.2347     -0.3436      0.2927     -0.4321      0.2062
# S=3     -0.3677     -0.9887     -0.0118      1.2718     -0.3399     -0.0152
# S=4     -0.2862     -0.9502      0.1680      0.8662     -0.5637     -0.0747
# S=5     -0.3766     -1.1532      0.1109      0.7916      0.0618     -0.3954
# S=6     -0.4089     -1.1321      0.1220      0.9455     -0.4143     -0.6954
# S=7     -0.5320     -0.8488      0.1963      0.8967     -0.0798     -2.1107
# S=8     -0.5729     -1.1584      0.2290      0.9922     -0.1838     -1.9828
# S=9     -2.0581     -1.3812      0.1563      0.8959     -0.3067     -2.2045
#
# 0        고용관련인증       지가경발간       지가경공시     소비자중심경영      지역사회공헌      정보보호공시  \
# S=2      5.9162     -0.2725      0.5228      0.6905      0.2517     -1.3671
# S=3     -4.1581     -1.1953     -1.0580      0.3336      0.9628     -0.8750
# S=4      7.5838     -2.0300     -0.5787     -0.8310      0.6544     -1.1315
# S=5      7.6903     -2.4902     -1.4986      1.0058     -8.1987     -0.8504
# S=6      8.5234     -2.5637     -1.2228     -8.2611      0.6591     -1.6434
# S=7      7.5389     -4.3027     -6.8410     -1.6041     -8.6521     -1.5742
# S=8      6.6526     -4.7783      1.0152     -1.0060     -0.7930     -2.0336
# S=9      5.7281     -4.5559      3.7657     -9.3887     -8.6937     -2.0831
#
# 0        잡플래닛평점       신규채용률       기부_투자      S_risk       const
# S=2      0.0113     -0.6174     -1.8465      0.3788      3.4887
# S=3     -0.1579     -0.2311     -0.2751     -0.7270      4.1427
# S=4     -0.7032     -0.5135     -0.6256     -0.1473      5.2093
# S=5     -0.4524     -0.6647     -0.7519     -0.4602      5.4402
# S=6     -0.5706     -0.3583     -2.1279     -0.3328      6.0219
# S=7     -0.6296     -0.6102     -1.9267     -0.5136      6.4888
# S=8     -1.2623     -0.6691     -2.1732     -0.6388      6.8600
# S=9     -1.3669     -0.7301     -4.6474     -0.7296     -0.9825
# ###  7 th selected model ###
# AIC:  2118.2698184631777 dropped value:  정규직비율
# 0       ESG임원비율     업종별여성비율       인력유지율  여성평균급여대비총합      가족친화인증      고용관련인증  \
# S=2     -0.2183     -1.1983      0.4327     -0.5612      0.1086      7.0209
# S=3     -0.3656     -0.9723      1.2852     -0.3369     -0.0480     -3.7917
# S=4     -0.2902     -0.9348      0.8378     -0.5038     -0.1599      8.7221
# S=5     -0.3772     -1.1426      0.7813      0.0948     -0.4733      8.8294
# S=6     -0.4126     -1.1222      0.9462     -0.3696     -0.7716      9.6416
# S=7     -0.5426     -0.8514      0.8755     -0.0182     -2.2530      8.6818
# S=8     -0.5868     -1.1578      0.9573     -0.1174     -2.1585      7.8362
# S=9     -2.0687     -1.3813      0.8879     -0.2514     -2.3117      6.8199
#
# 0         지가경발간       지가경공시     소비자중심경영      지역사회공헌      정보보호공시      잡플래닛평점  \
# S=2     -0.2003      0.3935      0.7319      0.2462     -1.2845     -0.1893
# S=3     -1.2013     -1.0794      0.3418      1.0942     -0.7883     -0.2164
# S=4     -2.0028     -0.5416     -0.7867      0.8058     -1.0696     -0.7317
# S=5     -2.4550     -1.5185      1.0586     -8.2828     -0.7457     -0.5163
# S=6     -2.5156     -1.2342     -8.4918      0.8327     -1.5539     -0.6224
# S=7     -4.3146     -7.0881     -1.4954     -8.7387     -1.5414     -0.6913
# S=8     -4.7993      1.0957     -0.8922     -0.7518     -2.0371     -1.3278
# S=9     -4.5450      3.4773     -9.3987     -8.7081     -2.0138     -1.4153
#
# 0         신규채용률       기부_투자      S_risk       const
# S=2     -0.6501     -1.8821      0.4156      3.7176
# S=3     -0.2443     -0.2530     -0.7343      4.1425
# S=4     -0.5462     -0.5361     -0.2008      5.1955
# S=5     -0.7036     -0.6530     -0.5070      5.4089
# S=6     -0.3862     -2.0477     -0.3743      5.9834
# S=7     -0.6539     -1.8278     -0.5571      6.4946
# S=8     -0.7172     -2.0891     -0.6822      6.8966
# S=9     -0.7700     -4.2918     -0.7725     -1.0259
# ###  8 th selected model ###
# AIC:  2113.7942642858634 dropped value:  고용관련인증
# 0       ESG임원비율     업종별여성비율       인력유지율  여성평균급여대비총합      가족친화인증       지가경발간  \
# S=2     -0.2165     -1.0490      0.2864     -0.6430      0.0896     -0.3665
# S=3     -0.3626     -0.8303      1.1519     -0.4068     -0.0639     -1.3458
# S=4     -0.2866     -0.7941      0.7236     -0.5583     -0.1687     -2.1447
# S=5     -0.3724     -0.9996      0.6746      0.0473     -0.4810     -2.5884
# S=6     -0.4049     -0.9673      0.8969     -0.4018     -0.7495     -2.6134
# S=7     -0.5358     -0.7108      0.7682     -0.0670     -2.2618     -4.4608
# S=8     -0.5782     -1.0216      0.8306     -0.1681     -2.1711     -5.0233
# S=9     -1.9959     -1.2440      0.7495     -0.3037     -2.3159     -4.7908
#
# 0         지가경공시     소비자중심경영      지역사회공헌      정보보호공시      잡플래닛평점       신규채용률  \
# S=2      0.5474      0.6585      0.2435     -1.4713     -0.1548     -0.6614
# S=3     -0.9528      0.2868      1.1351     -0.9314     -0.1814     -0.2421
# S=4     -0.4174     -0.8670      0.8176     -1.2447     -0.7064     -0.5533
# S=5     -1.4031      0.9756     -7.1612     -0.9287     -0.4954     -0.7113
# S=6     -1.1589     -7.3966      0.8006     -1.7487     -0.5955     -0.3889
# S=7     -6.1080     -1.5761     -7.6554     -1.7193     -0.6711     -0.6648
# S=8      1.2948     -0.9531     -0.7494     -2.2258     -1.3133     -0.7319
# S=9      3.7320     -8.3775     -7.6284     -2.2093     -1.4003     -0.7858
#
# 0         기부_투자      S_risk       const
# S=2     -2.1796      1.0186      3.2406
# S=3     -0.4499     -0.2366      3.6825
# S=4     -0.8121      0.3190      4.8271
# S=5     -0.9291      0.0070      5.0599
# S=6     -2.4570      0.1609      5.7186
# S=7     -2.0932     -0.0466      6.1449
# S=8     -2.3096     -0.1731      6.5338
# S=9     -4.5271     -0.2591     -1.0608
# ###  9 th selected model ###
# AIC:  2110.7368957149647 dropped value:  인력유지율
# 0       ESG임원비율     업종별여성비율  여성평균급여대비총합      가족친화인증       지가경발간       지가경공시  \
# S=2     -0.2009     -0.9679     -0.6130      0.1824     -0.1970      0.5587
# S=3     -0.3335     -0.7759     -0.3488      0.0411     -1.3869     -0.8111
# S=4     -0.2583     -0.7397     -0.4986     -0.0809     -2.0693     -0.3512
# S=5     -0.3429     -0.9516      0.1182     -0.3920     -2.5015     -1.3278
# S=6     -0.3761     -0.9320     -0.3226     -0.6917     -2.6019     -1.0704
# S=7     -0.5033     -0.6676      0.0090     -2.1842     -4.4211     -5.8231
# S=8     -0.5450     -0.9749     -0.0942     -2.0989     -4.9796      1.4190
# S=9     -1.8702     -1.2046     -0.2288     -2.2409     -4.7326      3.8685
#
# 0       소비자중심경영      지역사회공헌      정보보호공시      잡플래닛평점       신규채용률       기부_투자  \
# S=2      0.5674      0.3690     -1.3449     -0.1561     -0.5710     -1.9555
# S=3     -0.0683      1.1853     -0.6669     -0.1151     -0.0554     -0.2974
# S=4     -1.0463      0.9441     -1.0377     -0.6767     -0.4293     -0.6661
# S=5      0.8027     -6.6268     -0.7163     -0.4676     -0.5908     -0.8153
# S=6     -7.2413      0.8500     -1.5225     -0.5571     -0.2558     -2.2901
# S=7     -1.7617     -7.1093     -1.4927     -0.6408     -0.5412     -1.9567
# S=8     -1.1664     -0.6243     -1.9949     -1.2780     -0.6044     -2.1729
# S=9     -8.2250     -7.0330     -1.9909     -1.3714     -0.6631     -4.4214
#
# 0        S_risk       const
# S=2      0.8574      2.7951
# S=3     -0.3358      3.1757
# S=4      0.2262      4.2945
# S=5     -0.0796      4.5329
# S=6      0.0851      5.2099
# S=7     -0.1345      5.6295
# S=8     -0.2583      6.0288
# S=9     -0.3470     -1.0904
# ###  10 th selected model ###
# AIC:  2108.482582385456 dropped value:  여성평균급여대비총합
# 0       ESG임원비율     업종별여성비율      가족친화인증       지가경발간       지가경공시     소비자중심경영  \
# S=2     -0.1868     -0.9003      0.1460     -0.2324      0.4655      0.4313
# S=3     -0.3197     -0.7197      0.0696     -1.4916     -0.8854     -0.1469
# S=4     -0.2424     -0.6741     -0.0659     -2.1645     -0.4345     -1.0994
# S=5     -0.3489     -0.9197     -0.3191     -2.5071     -1.3125      0.7135
# S=6     -0.3639     -0.8941     -0.6628     -2.6929     -1.1747     -7.1804
# S=7     -0.5158     -0.6258     -2.0985     -4.4495     -5.5235     -1.8472
# S=8     -0.5541     -0.9261     -2.0319     -4.9834      1.2668     -1.2036
# S=9     -1.8663     -1.1680     -2.1801     -4.7537      3.7222     -8.1073
#
# 0        지역사회공헌      정보보호공시      잡플래닛평점       신규채용률       기부_투자      S_risk  \
# S=2      0.0698     -1.3564     -0.1430     -0.4841     -2.0620      0.8116
# S=3      0.9477     -0.6389     -0.0976      0.0195     -0.3208     -0.3608
# S=4      0.6839     -1.0158     -0.6563     -0.3493     -0.6472      0.1449
# S=5     -6.5026     -0.6959     -0.4774     -0.5184     -0.9555     -0.0861
# S=6      0.6214     -1.5012     -0.5465     -0.1701     -2.3312      0.0630
# S=7     -7.0454     -1.4610     -0.6315     -0.4757     -2.0492     -0.1556
# S=8     -0.7967     -1.9537     -1.2620     -0.5299     -2.2470     -0.2768
# S=9     -7.0580     -1.9737     -1.3563     -0.5747     -4.4850     -0.3535
#
# 0         const
# S=2      3.0175
# S=3      3.2542
# S=4      4.4336
# S=5      4.5251
# S=6      5.2867
# S=7      5.5479
# S=8      5.9565
# S=9     -1.0728
# ###  11 th selected model ###
# AIC:  2107.1374670561436 dropped value:  신규채용률
# 0       ESG임원비율     업종별여성비율      가족친화인증       지가경발간       지가경공시     소비자중심경영  \
# S=2     -0.1890     -0.8218      0.2850     -0.4187      0.4577      0.5730
# S=3     -0.3114     -0.6748      0.1027     -1.5736     -0.7737      0.0861
# S=4     -0.2419     -0.5992      0.0399     -2.3227     -0.4085     -0.9712
# S=5     -0.3513     -0.8579     -0.2366     -2.5810     -1.3818      0.7813
# S=6     -0.3598     -0.8138     -0.5556     -2.8458     -1.0815     -7.5685
# S=7     -0.5126     -0.5588     -2.0176     -4.5400     -5.7842     -1.7613
# S=8     -0.5512     -0.8585     -1.9633     -5.0200      1.2074     -1.1548
# S=9     -1.8649     -1.1111     -2.1332     -4.7364      3.6648     -8.5451
#
# 0        지역사회공헌      정보보호공시      잡플래닛평점       기부_투자      S_risk       const
# S=2     -0.1119     -1.4239     -0.0467     -2.3272      0.6756      2.9601
# S=3      0.8268     -0.6689     -0.0297     -0.2009     -0.4230      3.2096
# S=4      0.5789     -1.0662     -0.5565     -0.8706      0.0801      4.3176
# S=5     -7.2174     -0.6964     -0.3992     -1.4546     -0.1211      4.4501
# S=6      0.5199     -1.5084     -0.4397     -2.3218     -0.0314      5.1277
# S=7     -7.8345     -1.4760     -0.5483     -2.5236     -0.1927      5.4893
# S=8     -0.9695     -1.9674     -1.1866     -2.8214     -0.3059      5.9303
# S=9     -7.9356     -1.9910     -1.2868     -5.2207     -0.3745     -1.0702
# ###  12 th selected model ###
# AIC:  2105.6793242619506 dropped value:  지가경공시
# 0       ESG임원비율     업종별여성비율      가족친화인증       지가경발간     소비자중심경영      지역사회공헌  \
# S=2     -0.1774     -0.8029      0.2849     -0.3085      0.5830      0.0189
# S=3     -0.3107     -0.6626      0.0764     -1.9874      0.1605      0.7698
# S=4     -0.2402     -0.5794      0.0162     -2.5686     -0.9420      0.5168
# S=5     -0.3559     -0.8518     -0.2602     -3.1210      0.8660     -6.6058
# S=6     -0.3649     -0.7953     -0.5807     -3.2489     -6.6120      0.4526
# S=7     -0.5150     -0.5370     -2.0539     -5.1276     -1.6832     -7.0747
# S=8     -0.5517     -0.8308     -2.0062     -4.6715     -1.0764     -1.0116
# S=9     -1.8850     -1.0797     -2.2023     -3.7792     -7.7453     -7.1446
#
# 0        정보보호공시      잡플래닛평점       기부_투자      S_risk       const
# S=2     -1.4301     -0.0660     -2.1507      0.6652      3.0327
# S=3     -0.6756     -0.0504     -0.3211     -0.4259      3.3240
# S=4     -1.0814     -0.5692     -0.9644      0.0821      4.4239
# S=5     -0.7174     -0.4160     -1.6271     -0.1172      4.5445
# S=6     -1.5147     -0.4588     -2.4775     -0.0347      5.2033
# S=7     -1.4671     -0.5593     -2.6397     -0.1942      5.5673
# S=8     -1.9419     -1.1931     -2.7620     -0.3080      6.0069
# S=9     -1.9456     -1.2889     -4.0147     -0.3769     -1.0976
# ###  13 th selected model ###
# AIC:  2105.522334148442 dropped value:  지역사회공헌
# 0       ESG임원비율     업종별여성비율      가족친화인증       지가경발간     소비자중심경영      정보보호공시  \
# S=2     -0.1757     -0.8075      0.2815     -0.2870      0.5931     -1.4049
# S=3     -0.3171     -0.6823      0.2092     -1.9666      0.0844     -0.7704
# S=4     -0.2429     -0.5956      0.1002     -2.5446     -0.9684     -1.1279
# S=5     -0.3464     -0.8485     -0.3234     -3.1573      0.8385     -0.6472
# S=6     -0.3649     -0.7947     -0.5366     -3.2350     -6.3707     -1.5194
# S=7     -0.5072     -0.5502     -2.0634     -5.0969     -1.6961     -1.4400
# S=8     -0.5465     -0.8399     -2.0089     -4.6449     -1.1002     -1.9237
# S=9     -1.8944     -1.0958     -2.2152     -3.7340     -7.5490     -1.9237
#
# 0        잡플래닛평점       기부_투자      S_risk       const
# S=2     -0.0744     -2.1358      0.6603      2.9971
# S=3     -0.0348     -0.2860     -0.4004      3.3118
# S=4     -0.5569     -0.9314      0.0903      4.3967
# S=5     -0.4184     -1.5869     -0.1472      4.4945
# S=6     -0.4525     -2.4294     -0.0408      5.1778
# S=7     -0.5610     -2.6068     -0.2057      5.5194
# S=8     -1.1926     -2.7170     -0.3193      5.9610
# S=9     -1.2901     -3.9635     -0.3897     -1.2337
# ###  14 th selected model ###
# AIC:  2105.522334148442 dropped value:  no
# 0       ESG임원비율     업종별여성비율      가족친화인증       지가경발간     소비자중심경영      정보보호공시  \
# S=2     -0.1757     -0.8075      0.2815     -0.2870      0.5931     -1.4049
# S=3     -0.3171     -0.6823      0.2092     -1.9666      0.0844     -0.7704
# S=4     -0.2429     -0.5956      0.1002     -2.5446     -0.9684     -1.1279
# S=5     -0.3464     -0.8485     -0.3234     -3.1573      0.8385     -0.6472
# S=6     -0.3649     -0.7947     -0.5366     -3.2350     -6.3707     -1.5194
# S=7     -0.5072     -0.5502     -2.0634     -5.0969     -1.6961     -1.4400
# S=8     -0.5465     -0.8399     -2.0089     -4.6449     -1.1002     -1.9237
# S=9     -1.8944     -1.0958     -2.2152     -3.7340     -7.5490     -1.9237
#
# 0        잡플래닛평점       기부_투자      S_risk       const
# S=2     -0.0744     -2.1358      0.6603      2.9971
# S=3     -0.0348     -0.2860     -0.4004      3.3118
# S=4     -0.5569     -0.9314      0.0903      4.3967
# S=5     -0.4184     -1.5869     -0.1472      4.4945
# S=6     -0.4525     -2.4294     -0.0408      5.1778
# S=7     -0.5610     -2.6068     -0.2057      5.5194
# S=8     -1.1926     -2.7170     -0.3193      5.9610
# S=9     -1.2901     -3.9635     -0.3897     -1.2337

# %% [markdown]
# - 위 후진제거법으로 선택한 모형들의 AIC, 각 단계마다 제거된 변수, summary를 통해 얻은 회귀계수 값을 출력한다.
# - Social data의 경우에는 계산된 AIC가 가장 작은 모형보다는 다른 4가지 지표도 고려하여 각 모형에 대한 AIC와 4가지 지표가 표시된 표에서 6번 모형을 선택하기로 했다. 6번 모형 보다는 5번 모형이 더 좋아보이지만 상관계수 그래프에서도 알 수 있듯이 여성직원비율과 업종별 여성비율의 높은 상관관계를 확인할 수 있기 때문에 두 변수 중 AIC를 더 낮게 만드는 여성직원비율을 제거함으로써 설명력은 물론 multicollinearity까지 방지할 수 있다고 판단해 6번 모형을 선택했다.
# - 제거된 변수는 [여성임원비율, 미등기여성임원비율21, 여성평균근속연수대비총합, ESG채권, 공정위위반횟수, 여성직원비율]이다.
# - 남은 변수는 [ESG임원비율, 업종별여성비율, 정규직비율, 인력유지율, 여성평균급여대비총합, 가족친화인증, 고용관련인증, 지가경발간, 지가경공시, 소비자중심경영, 지역사회공헌, 정보보호공시, 잡플래닛평점, 신규채용률, 기부_투자, S_risk]이다. 이 변수들을 사용하여 최종 결과 모델을 적합하기로 했다.

# %% [markdown]
# #### variable selection에 따른 Final Fitting

# %%
## variable selection에 따라 data에 불필요한 covariate들을 delete ## 회의 후 수정
y_train = r_train['S_GRADE']
x_train = r_train.drop(columns=['종목코드','회사명','SICS_Sector_Kr','S_GRADE','Stratify'], 
                     inplace=False)
x_train.drop(columns=['여성임원비율','미등기여성임원비율21','여성평균근속연수대비총합','ESG채권',
                      '공정위위반횟수','여성직원비율'], inplace=True)
x = sm.add_constant(x_train, prepend=False)
model = sm.MNLogit(y_train, x)
result = model.fit(method='lbfgs', maxiter=100000, full_output=True)
mar=result.get_margeff()
y_pred = model.predict(result.params, x)
y_pred = y_pred.argmax(1) + 1
y_pred = pd.Series(y_pred)
## 모형 fitting 결과
print("[Logistic Regression Train Set Evaluation]")
eval_stat(make_confusionmatrix(y_train, y_pred))
# Out:
# [Logistic Regression Train Set Evaluation]
# 정확도 :  43.87 %
# 근접정확도 :  78.67 %
# 과소적합/오류 비 :  59.84 %
# 3등급이상과적합/오류 비 :  18.33 %

# %% [markdown]
# - AIC를 기준으로 변수를 선택한 후, train set에 대해서 fitting 한 결과는 다음과 같다.
# - 정확도는 43.87 %, 근접정확도는 78.67%, 과소적합/오류비는 59.84%, 3등급이상과적합오류비는 18.33%이다.
# - 모든 변수를 사용했을 때와 클수록 좋은 정확도의 경우 변수 선택 이후 감소했으나 근접정확도, 과소적합오류비의 경우 변수 선택 이후 증가했고, 작을수록 좋은 3등급이상과적합오류비는 감소했다. 4가지 지표에 대해서 변수 선택 이후가 더 좋은 값을 보이므로 변수 선택이 타당하다고 판단했다.

# %%
print("### print model summary ###")
print(result.summary())
# Out:
# ### print model summary ###
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                S_GRADE   No. Observations:                  661
# Model:                        MNLogit   Df Residuals:                      525
# Method:                           MLE   Df Model:                          128
# Date:                Fri, 14 Oct 2022   Pseudo R-squ.:                  0.2784
# Time:                        21:38:47   Log-Likelihood:                -925.71
# converged:                       True   LL-Null:                       -1282.8
# Covariance Type:            nonrobust   LLR p-value:                 3.330e-82
# ==============================================================================
#  S_GRADE=2       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ESG임원비율       -0.2237      0.117     -1.919      0.055      -0.452       0.005
# 업종별여성비율       -1.2347      0.476     -2.595      0.009      -2.167      -0.302
# 정규직비율         -0.3436      0.323     -1.065      0.287      -0.976       0.289
# 인력유지율          0.2927      0.488      0.600      0.549      -0.664       1.249
# 여성평균급여대비총합    -0.4321      0.532     -0.812      0.417      -1.476       0.611
# 가족친화인증         0.2062      0.829      0.249      0.804      -1.419       1.831
# 고용관련인증         5.9162      9.733      0.608      0.543     -13.161      24.993
# 지가경발간         -0.2725      1.505     -0.181      0.856      -3.223       2.678
# 지가경공시          0.5228      0.820      0.637      0.524      -1.085       2.130
# 소비자중심경영        0.6905      1.354      0.510      0.610      -1.963       3.344
# 지역사회공헌         0.2517      1.397      0.180      0.857      -2.487       2.990
# 정보보호공시        -1.3671      1.054     -1.298      0.194      -3.432       0.698
# 잡플래닛평점         0.0113      0.645      0.017      0.986      -1.254       1.276
# 신규채용률         -0.6174      0.399     -1.548      0.122      -1.399       0.164
# 기부_투자         -1.8465      1.492     -1.238      0.216      -4.770       1.077
# S_risk         0.3788      0.843      0.449      0.653      -1.273       2.031
# const          3.4887      1.856      1.880      0.060      -0.148       7.126
# ------------------------------------------------------------------------------
#  S_GRADE=3       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ESG임원비율       -0.3677      0.125     -2.953      0.003      -0.612      -0.124
# 업종별여성비율       -0.9887      0.485     -2.037      0.042      -1.940      -0.038
# 정규직비율         -0.0118      0.313     -0.038      0.970      -0.625       0.602
# 인력유지율          1.2718      0.502      2.536      0.011       0.289       2.255
# 여성평균급여대비총합    -0.3399      0.516     -0.659      0.510      -1.351       0.671
# 가족친화인증        -0.0152      0.842     -0.018      0.986      -1.666       1.636
# 고용관련인증        -4.1581    363.944     -0.011      0.991    -717.476     709.159
# 지가경발간         -1.1953      1.444     -0.828      0.408      -4.026       1.636
# 지가경공시         -1.0580      0.863     -1.226      0.220      -2.750       0.634
# 소비자중심경영        0.3336      1.459      0.229      0.819      -2.526       3.194
# 지역사회공헌         0.9628      1.419      0.678      0.498      -1.819       3.745
# 정보보호공시        -0.8750      1.079     -0.811      0.417      -2.990       1.240
# 잡플래닛평점        -0.1579      0.632     -0.250      0.803      -1.396       1.080
# 신규채용률         -0.2311      0.431     -0.536      0.592      -1.077       0.615
# 기부_투자         -0.2751      1.498     -0.184      0.854      -3.212       2.662
# S_risk        -0.7270      0.822     -0.884      0.377      -2.339       0.885
# const          4.1427      1.839      2.253      0.024       0.538       7.747
# ------------------------------------------------------------------------------
#  S_GRADE=4       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ESG임원비율       -0.2862      0.124     -2.311      0.021      -0.529      -0.043
# 업종별여성비율       -0.9502      0.485     -1.959      0.050      -1.901       0.001
# 정규직비율          0.1680      0.304      0.552      0.581      -0.429       0.765
# 인력유지율          0.8662      0.497      1.744      0.081      -0.108       1.840
# 여성평균급여대비총합    -0.5637      0.519     -1.085      0.278      -1.582       0.454
# 가족친화인증        -0.0747      0.850     -0.088      0.930      -1.740       1.590
# 고용관련인증         7.5838     10.317      0.735      0.462     -12.637      27.804
# 지가경발간         -2.0300      1.439     -1.410      0.158      -4.851       0.791
# 지가경공시         -0.5787      0.900     -0.643      0.520      -2.343       1.186
# 소비자중심경영       -0.8310      1.659     -0.501      0.616      -4.083       2.421
# 지역사회공헌         0.6544      1.461      0.448      0.654      -2.209       3.517
# 정보보호공시        -1.1315      1.077     -1.051      0.293      -3.242       0.979
# 잡플래닛평점        -0.7032      0.642     -1.095      0.273      -1.961       0.555
# 신규채용률         -0.5135      0.415     -1.238      0.216      -1.326       0.299
# 기부_투자         -0.6256      1.494     -0.419      0.675      -3.553       2.302
# S_risk        -0.1473      0.834     -0.177      0.860      -1.781       1.487
# const          5.2093      1.815      2.870      0.004       1.651       8.767
# ------------------------------------------------------------------------------
#  S_GRADE=5       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ESG임원비율       -0.3766      0.140     -2.687      0.007      -0.651      -0.102
# 업종별여성비율       -1.1532      0.498     -2.316      0.021      -2.129      -0.177
# 정규직비율          0.1109      0.312      0.355      0.722      -0.501       0.723
# 인력유지율          0.7916      0.505      1.567      0.117      -0.199       1.782
# 여성평균급여대비총합     0.0618      0.529      0.117      0.907      -0.975       1.099
# 가족친화인증        -0.3954      0.868     -0.456      0.649      -2.097       1.306
# 고용관련인증         7.6903     10.335      0.744      0.457     -12.565      27.946
# 지가경발간         -2.4902      1.482     -1.680      0.093      -5.396       0.415
# 지가경공시         -1.4986      1.134     -1.322      0.186      -3.720       0.723
# 소비자중심경영        1.0058      1.470      0.684      0.494      -1.875       3.887
# 지역사회공헌        -8.1987     38.564     -0.213      0.832     -83.782      67.385
# 정보보호공시        -0.8504      1.098     -0.775      0.439      -3.002       1.301
# 잡플래닛평점        -0.4524      0.646     -0.700      0.484      -1.719       0.814
# 신규채용률         -0.6647      0.412     -1.612      0.107      -1.473       0.144
# 기부_투자         -0.7519      1.519     -0.495      0.620      -3.728       2.224
# S_risk        -0.4602      0.827     -0.556      0.578      -2.082       1.161
# const          5.4402      1.847      2.946      0.003       1.820       9.060
# ------------------------------------------------------------------------------
#  S_GRADE=6       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ESG임원비율       -0.4089      0.150     -2.719      0.007      -0.704      -0.114
# 업종별여성비율       -1.1321      0.506     -2.239      0.025      -2.123      -0.141
# 정규직비율          0.1220      0.312      0.391      0.696      -0.489       0.733
# 인력유지율          0.9455      0.506      1.868      0.062      -0.046       1.937
# 여성평균급여대비총합    -0.4143      0.531     -0.781      0.435      -1.454       0.626
# 가족친화인증        -0.6954      0.892     -0.779      0.436      -2.444       1.054
# 고용관련인증         8.5234     10.323      0.826      0.409     -11.708      28.755
# 지가경발간         -2.5637      1.535     -1.670      0.095      -5.573       0.445
# 지가경공시         -1.2228      1.428     -0.856      0.392      -4.021       1.576
# 소비자중심경영       -8.2611     42.428     -0.195      0.846     -91.419      74.897
# 지역사회공헌         0.6591      1.590      0.415      0.678      -2.457       3.775
# 정보보호공시        -1.6434      1.099     -1.496      0.135      -3.797       0.510
# 잡플래닛평점        -0.5706      0.648     -0.881      0.378      -1.840       0.699
# 신규채용률         -0.3583      0.437     -0.821      0.412      -1.214       0.497
# 기부_투자         -2.1279      1.566     -1.359      0.174      -5.197       0.941
# S_risk        -0.3328      0.830     -0.401      0.688      -1.960       1.294
# const          6.0219      1.863      3.232      0.001       2.370       9.674
# ------------------------------------------------------------------------------
#  S_GRADE=7       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ESG임원비율       -0.5320      0.168     -3.163      0.002      -0.862      -0.202
# 업종별여성비율       -0.8488      0.495     -1.716      0.086      -1.818       0.121
# 정규직비율          0.1963      0.307      0.641      0.522      -0.404       0.797
# 인력유지율          0.8967      0.497      1.803      0.071      -0.078       1.872
# 여성평균급여대비총합    -0.0798      0.521     -0.153      0.878      -1.102       0.942
# 가족친화인증        -2.1107      0.915     -2.307      0.021      -3.903      -0.318
# 고용관련인증         7.5389     10.329      0.730      0.465     -12.706      27.784
# 지가경발간         -4.3027      1.758     -2.448      0.014      -7.748      -0.858
# 지가경공시         -6.8410     30.811     -0.222      0.824     -67.229      53.548
# 소비자중심경영       -1.6041      1.813     -0.885      0.376      -5.158       1.950
# 지역사회공헌        -8.6521     38.731     -0.223      0.823     -84.564      67.260
# 정보보호공시        -1.5742      1.085     -1.450      0.147      -3.702       0.553
# 잡플래닛평점        -0.6296      0.640     -0.984      0.325      -1.883       0.624
# 신규채용률         -0.6102      0.418     -1.461      0.144      -1.429       0.208
# 기부_투자         -1.9267      1.574     -1.224      0.221      -5.012       1.159
# S_risk        -0.5136      0.822     -0.625      0.532      -2.125       1.098
# const          6.4888      1.894      3.426      0.001       2.777      10.201
# ------------------------------------------------------------------------------
#  S_GRADE=8       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ESG임원비율       -0.5729      0.177     -3.233      0.001      -0.920      -0.226
# 업종별여성비율       -1.1584      0.491     -2.357      0.018      -2.122      -0.195
# 정규직비율          0.2290      0.305      0.751      0.453      -0.369       0.827
# 인력유지율          0.9922      0.494      2.009      0.044       0.024       1.960
# 여성평균급여대비총합    -0.1838      0.518     -0.355      0.723      -1.200       0.832
# 가족친화인증        -1.9828      0.894     -2.218      0.027      -3.735      -0.231
# 고용관련인증         6.6526     10.339      0.643      0.520     -13.611      26.916
# 지가경발간         -4.7783      1.782     -2.681      0.007      -8.271      -1.286
# 지가경공시          1.0152      1.769      0.574      0.566      -2.451       4.482
# 소비자중심경영       -1.0060      1.672     -0.602      0.547      -4.283       2.271
# 지역사회공헌        -0.7930      1.738     -0.456      0.648      -4.200       2.614
# 정보보호공시        -2.0336      1.080     -1.882      0.060      -4.151       0.084
# 잡플래닛평점        -1.2623      0.639     -1.975      0.048      -2.515      -0.009
# 신규채용률         -0.6691      0.415     -1.612      0.107      -1.483       0.145
# 기부_투자         -2.1732      1.595     -1.363      0.173      -5.299       0.953
# S_risk        -0.6388      0.821     -0.779      0.436      -2.247       0.969
# const          6.8600      1.913      3.586      0.000       3.111      10.609
# ------------------------------------------------------------------------------
#  S_GRADE=9       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ESG임원비율       -2.0581     17.506     -0.118      0.906     -36.369      32.252
# 업종별여성비율       -1.3812      0.493     -2.801      0.005      -2.348      -0.415
# 정규직비율          0.1563      0.306      0.511      0.609      -0.443       0.755
# 인력유지율          0.8959      0.495      1.811      0.070      -0.074       1.866
# 여성평균급여대비총합    -0.3067      0.520     -0.590      0.555      -1.325       0.712
# 가족친화인증        -2.2045      0.919     -2.398      0.016      -4.006      -0.403
# 고용관련인증         5.7281     10.375      0.552      0.581     -14.606      26.063
# 지가경발간         -4.5559      1.816     -2.508      0.012      -8.116      -0.996
# 지가경공시          3.7657      2.115      1.780      0.075      -0.381       7.912
# 소비자중심경영       -9.3887     40.740     -0.230      0.818     -89.237      70.460
# 지역사회공헌        -8.6937     38.719     -0.225      0.822     -84.581      67.194
# 정보보호공시        -2.0831      1.085     -1.919      0.055      -4.210       0.044
# 잡플래닛평점        -1.3669      0.641     -2.133      0.033      -2.623      -0.111
# 신규채용률         -0.7301      0.415     -1.758      0.079      -1.544       0.084
# 기부_투자         -4.6474      2.222     -2.091      0.037      -9.003      -0.291
# S_risk        -0.7296      0.821     -0.889      0.374      -2.338       0.879
# const         -0.9825     91.034     -0.011      0.991    -179.405     177.440
# ==============================================================================

# %% [markdown]
# - summary의 결과 R-squ값이 0.2784으로 전체 변수를 사용한 full model의 0.2941보다 작아져 설명력이 줄어들었다고 할 수 있지만 LLR p-value는 더 작아졌고, 중요하다고 생각하는 4가지 지표에 대해서 모두 좋아지는 모습을 보였기 때문에 여전히 변수선택이 합당하다고 판단했다.

# %% [markdown]
# #### variale selection 이후, 전체 모델에 대한 회귀계수 값 출력

# %%
print('### The selected model\'s regression coefficient ###')
check_beta(result)
# Out:
# ### The selected model's regression coefficient ###
# 0       ESG임원비율     업종별여성비율       정규직비율       인력유지율  여성평균급여대비총합      가족친화인증  \
# S=2     -0.2237     -1.2347     -0.3436      0.2927     -0.4321      0.2062
# S=3     -0.3677     -0.9887     -0.0118      1.2718     -0.3399     -0.0152
# S=4     -0.2862     -0.9502      0.1680      0.8662     -0.5637     -0.0747
# S=5     -0.3766     -1.1532      0.1109      0.7916      0.0618     -0.3954
# S=6     -0.4089     -1.1321      0.1220      0.9455     -0.4143     -0.6954
# S=7     -0.5320     -0.8488      0.1963      0.8967     -0.0798     -2.1107
# S=8     -0.5729     -1.1584      0.2290      0.9922     -0.1838     -1.9828
# S=9     -2.0581     -1.3812      0.1563      0.8959     -0.3067     -2.2045
#
# 0        고용관련인증       지가경발간       지가경공시     소비자중심경영      지역사회공헌      정보보호공시  \
# S=2      5.9162     -0.2725      0.5228      0.6905      0.2517     -1.3671
# S=3     -4.1581     -1.1953     -1.0580      0.3336      0.9628     -0.8750
# S=4      7.5838     -2.0300     -0.5787     -0.8310      0.6544     -1.1315
# S=5      7.6903     -2.4902     -1.4986      1.0058     -8.1987     -0.8504
# S=6      8.5234     -2.5637     -1.2228     -8.2611      0.6591     -1.6434
# S=7      7.5389     -4.3027     -6.8410     -1.6041     -8.6521     -1.5742
# S=8      6.6526     -4.7783      1.0152     -1.0060     -0.7930     -2.0336
# S=9      5.7281     -4.5559      3.7657     -9.3887     -8.6937     -2.0831
#
# 0        잡플래닛평점       신규채용률       기부_투자      S_risk       const
# S=2      0.0113     -0.6174     -1.8465      0.3788      3.4887
# S=3     -0.1579     -0.2311     -0.2751     -0.7270      4.1427
# S=4     -0.7032     -0.5135     -0.6256     -0.1473      5.2093
# S=5     -0.4524     -0.6647     -0.7519     -0.4602      5.4402
# S=6     -0.5706     -0.3583     -2.1279     -0.3328      6.0219
# S=7     -0.6296     -0.6102     -1.9267     -0.5136      6.4888
# S=8     -1.2623     -0.6691     -2.1732     -0.6388      6.8600
# S=9     -1.3669     -0.7301     -4.6474     -0.7296     -0.9825

# %% [markdown]
# #### variable selection 이후, 전체 모형에 대한 p-value 값 출력

# %%
print('### The selected model\'s regression coefficient\'s p-value is ###')
check_p_value(result)
# Out:
# ### The selected model's regression coefficient's p-value is ###
# 0   ESG임원비율 업종별여성비율   정규직비율   인력유지율 여성평균급여대비총합  가족친화인증  고용관련인증   지가경발간  \
# S=2   0.055   0.009   0.287   0.549      0.417   0.804   0.543   0.856
# S=3   0.003   0.042   0.970   0.011      0.510   0.986   0.991   0.408
# S=4   0.021   0.050   0.581   0.081      0.278   0.930   0.462   0.158
# S=5   0.007   0.021   0.722   0.117      0.907   0.649   0.457   0.093
# S=6   0.007   0.025   0.696   0.062      0.435   0.436   0.409   0.095
# S=7   0.002   0.086   0.522   0.071      0.878   0.021   0.465   0.014
# S=8   0.001   0.018   0.453   0.044      0.723   0.027   0.520   0.007
# S=9   0.906   0.005   0.609   0.070      0.555   0.016   0.581   0.012
#
# 0     지가경공시 소비자중심경영  지역사회공헌  정보보호공시  잡플래닛평점   신규채용률   기부_투자  S_risk   const
# S=2   0.524   0.610   0.857   0.194   0.986   0.122   0.216   0.653   0.060
# S=3   0.220   0.819   0.498   0.417   0.803   0.592   0.854   0.377   0.024
# S=4   0.520   0.616   0.654   0.293   0.273   0.216   0.675   0.860   0.004
# S=5   0.186   0.494   0.832   0.439   0.484   0.107   0.620   0.578   0.003
# S=6   0.392   0.846   0.678   0.135   0.378   0.412   0.174   0.688   0.001
# S=7   0.824   0.376   0.823   0.147   0.325   0.144   0.221   0.532   0.001
# S=8   0.566   0.547   0.648   0.060   0.048   0.107   0.173   0.436   0.000
# S=9   0.075   0.818   0.822   0.055   0.033   0.079   0.037   0.374   0.991

# %% [markdown]
# #### variable selection 이후, marginal model에 대한 회귀계수 값 출력

# %%
check_beta_mar(mar)
# Out:
# 0             ESG임원비율     업종별여성비율       정규직비율       인력유지율  여성평균급여대비총합  \
# S_GRADE=1      0.0047      0.0171      0.0015     -0.0109      0.0060
# S_GRADE=2      0.0047     -0.0134     -0.0140     -0.0170     -0.0058
# S_GRADE=3      0.0046      0.0019     -0.0031      0.0263     -0.0029
# S_GRADE=4      0.0109      0.0043      0.0061      0.0022     -0.0154
# S_GRADE=5      0.0185     -0.0047     -0.0004     -0.0066      0.0202
# S_GRADE=6      0.0204     -0.0020     -0.0012      0.0022     -0.0112
# S_GRADE=7      0.0492      0.0401      0.0035     -0.0042      0.0187
# S_GRADE=8      0.1171      0.0028      0.0132      0.0162      0.0097
# S_GRADE=9     -0.2302     -0.0460     -0.0056     -0.0081     -0.0194
#
# 0              가족친화인증      고용관련인증       지가경발간       지가경공시     소비자중심경영  \
# S_GRADE=1      0.0007     -0.0653      0.0187      0.0049      0.0012
# S_GRADE=2      0.0191      0.1005      0.0506      0.0415      0.0564
# S_GRADE=3      0.0318     -0.5009      0.0555     -0.0200      0.0950
# S_GRADE=4      0.0333      0.1527      0.0176      0.0071      0.0433
# S_GRADE=5      0.0504      0.1296      0.0447     -0.0442      0.2312
# S_GRADE=6      0.0411      0.1516      0.0584     -0.0307     -0.3359
# S_GRADE=7     -0.0599      0.1438     -0.0408     -0.9022      0.2763
# S_GRADE=8     -0.0404      0.0524     -0.1450      0.1955      0.8150
# S_GRADE=9     -0.0759     -0.1643     -0.0597      0.7481     -1.1825
#
# 0              지역사회공헌      정보보호공시      잡플래닛평점       신규채용률       기부_투자  \
# S_GRADE=1      0.0048      0.0184      0.0040      0.0078      0.0184
# S_GRADE=2      0.0513     -0.0145      0.0145     -0.0084     -0.0347
# S_GRADE=3      0.1648      0.0206      0.0192      0.0146      0.0610
# S_GRADE=4      0.1518      0.0085     -0.0089     -0.0010      0.0451
# S_GRADE=5     -0.3089      0.0429      0.0187     -0.0069      0.0761
# S_GRADE=6      0.2890     -0.0032      0.0161      0.0142     -0.0013
# S_GRADE=7     -0.5559      0.0248      0.0481      0.0022      0.0804
# S_GRADE=8      1.0748     -0.0498     -0.0506     -0.0055      0.1619
# S_GRADE=9     -0.8717     -0.0477     -0.0609     -0.0170     -0.4070
#
# 0              S_risk
# S_GRADE=1      0.0015
# S_GRADE=2      0.0253
# S_GRADE=3     -0.0229
# S_GRADE=4      0.0113
# S_GRADE=5      0.0004
# S_GRADE=6      0.0110
# S_GRADE=7      0.0083
# S_GRADE=8     -0.0087
# S_GRADE=9     -0.0262

# %% [markdown]
# #### variable selection 이후, marginal model에 대한 p-value 값 출력

# %%
check_p_value_mar(mar)
# Out:
# 0         ESG임원비율 업종별여성비율   정규직비율   인력유지율 여성평균급여대비총합  가족친화인증  고용관련인증   지가경발간  \
# S_GRADE=1   0.053   0.009   0.724   0.104      0.413   0.953   0.959   0.361
# S_GRADE=2   0.846   0.087   0.040   0.038      0.571   0.255   0.975   0.040
# S_GRADE=3   0.939   0.843   0.655   0.009      0.774   0.083   0.976   0.040
# S_GRADE=4   0.879   0.634   0.252   0.817      0.118   0.078   0.964   0.515
# S_GRADE=5   0.911   0.642   0.944   0.543      0.054   0.014   0.960   0.241
# S_GRADE=6   0.916   0.847   0.803   0.817      0.237   0.054   0.931   0.175
# S_GRADE=7   0.935   0.002   0.540   0.747      0.133   0.187   0.929   0.751
# S_GRADE=8   0.938   0.859   0.045   0.300      0.508   0.509   0.978   0.465
# S_GRADE=9   0.930   0.001   0.374   0.574      0.155   0.210   0.898   0.744
#
# 0           지가경공시 소비자중심경영  지역사회공헌  정보보호공시  잡플래닛평점   신규채용률   기부_투자  S_risk
# S_GRADE=1   0.686   0.966   0.925   0.221   0.664   0.179   0.391   0.903
# S_GRADE=2   0.305   0.617   0.773   0.440   0.155   0.135   0.131   0.098
# S_GRADE=3   0.886   0.706   0.640   0.330   0.045   0.150   0.023   0.022
# S_GRADE=4   0.964   0.879   0.665   0.672   0.400   0.892   0.100   0.413
# S_GRADE=5   0.897   0.625   0.894   0.056   0.089   0.272   0.039   0.964
# S_GRADE=6   0.932   0.891   0.665   0.873   0.106   0.157   0.976   0.247
# S_GRADE=7   0.793   0.854   0.903   0.391   0.000   0.816   0.377   0.367
# S_GRADE=8   0.888   0.818   0.775   0.190   0.002   0.612   0.364   0.383
# S_GRADE=9   0.501   0.847   0.884   0.183   0.000   0.070   0.117   0.002

# %% [markdown]
# #### Interpretation and Visualization

# %%
new_num_var = list(set(num_var) & set(x_train.columns))
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(
   x_train[new_num_var].values, i) for i in range(x_train[new_num_var].shape[1])]
vif["features"] = x_train[new_num_var].columns
print("### Train set VIF ###")
vif
# Out:
# ### Train set VIF ###
#    VIF Factor    features
# 0    1.223835     ESG임원비율
# 1    1.028215  여성평균급여대비총합
# 2    1.112538      잡플래닛평점
# 3    1.198749       정규직비율
# 4    1.037796       인력유지율
# 5    1.016618     업종별여성비율
# 6    1.148238      S_risk
# 7    1.131982       신규채용률

# %% [markdown]
# - train set의 VIF값은 위와 같다. 모두 10보다 훨씬 작아 다중공선성이 없을 것으로 해석할 수 있다.

# %%
plt.figure(figsize = (15,8))
sns.heatmap(x_train[new_num_var].corr(), annot=True,cmap='gist_heat_r')
plt.show()

# %% [markdown]
# - 상관계수 plot에서도 특별히 위험한 수준의 상관관계는 없는 것으로 해석할 수 있다. 따라서 train set이 Multinomial Logistic Model을 사용하여 적합 할 수 있고, 그 결과는 신뢰할 수 있다고 말할 수 있다.

# %% [markdown]
# ## 5. Estimation
# - r_test 사용 (scaling 및 dummy 생성 완료된 데이터)

# %%
# 추가로 drop할 변수 있으면 drop해주기
x_test = r_test.drop(columns=['종목코드','회사명','SICS_Sector_Kr','S_GRADE','Stratify'], 
                     inplace=False)

# 삭제할 변수 명 입력
x_test.drop(columns=['여성임원비율','미등기여성임원비율21','여성평균근속연수대비총합','ESG채권',
                      '공정위위반횟수','여성직원비율'], inplace=True)
x_test = sm.add_constant(x_test, prepend=False)
pred = model.predict(result.params, x_test)
pred = pred.argmax(1) + 1

S_result = copy.deepcopy(r_test)
S_result['pred_grade'] = pred
S_result=S_result[['종목코드','pred_grade']]

# %%
# S_result 데이터프레임 확인
S_result.head(5)
# Out:
#     종목코드  pred_grade
# 0  95570           7
# 1   6840           9
# 2  27410           9
# 3   1460           9
# 4   1040           6

# %%
#S_result 값 저장
S_result.to_csv("S_result.csv", index=False, encoding="utf-8-sig")

# %%
S_result['pred_grade'].value_counts()
# Out:
# 8    97
# 9    76
# 7    25
# 5    24
# 3    19
# 2    15
# 4    14
# 1     7
# 6     5
# Name: pred_grade, dtype: int64
